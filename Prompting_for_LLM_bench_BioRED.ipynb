# %%
def merge_csvs_to_df(folder):
    import os
    import csv
    import pandas as pd

    rows = []

    for root, _, files in os.walk(folder):
        for file in files:
            if file.endswith('.csv'):
                path = os.path.join(root, file)
                with open(path, newline='', encoding='utf-8') as f:
                    reader = csv.DictReader(f)
                    for row in reader:
                        rows.append(row)

    df = pd.DataFrame(rows)
    # Ensure correct types for sorting
    df['doc_id'] = df['doc_id'].astype(str)
    df['entity1_offset'] = pd.to_numeric(df['entity1_offset'])
    df['entity2_offset'] = pd.to_numeric(df['entity2_offset'])
    # Sort by doc_id, then offsets
    df = df.sort_values(by=['doc_id', 'entity1_offset', 'entity2_offset']).reset_index(drop=True)
    # Remove duplicate rows
    df = df.drop_duplicates().reset_index(drop=True)

    return df

folder = "Sorted data/relation_specific/relation_specific_test"
merged_df_test = merge_csvs_to_df(folder)
print(merged_df_test.shape)  # Print shape of the merged DataFrame
print(merged_df_test.head()) # Print first few rows 
folder_train = "Sorted data/relation_specific/relation_specific_train"
merged_df_train = merge_csvs_to_df(folder_train)
print(merged_df_train.shape)  # Print shape of the merged DataFrame
# Out:
# (2116, 20)
#           relation_type filename count percentage    doc_id  \
# 0           Association      NaN   NaN        NaN  15000256
# 1           Association      NaN   NaN        NaN  15000256
# 2           Association      NaN   NaN        NaN  15000256
# 3  Positive_Correlation      NaN   NaN        NaN  15000256
# 4  Positive_Correlation      NaN   NaN        NaN  15000256
#
#                                         passage_text   entity1_id  \
# 0  Single-strand conformation polymorphism analys...         2332
# 1  Single-strand conformation polymorphism analys...         2332
# 2  Single-strand conformation polymorphism analys...         2332
# 3  Single-strand conformation polymorphism analys...  rs782013865
# 4  Single-strand conformation polymorphism analys...  rs782013865
#
#                                 entity1_text       entity1_type  \
# 0                                   ['FMR1']  GeneOrGeneProduct
# 1                                   ['FMR1']  GeneOrGeneProduct
# 2                                   ['FMR1']  GeneOrGeneProduct
# 3  ['A to C substitution at nucleotide 879']    SequenceVariant
# 4  ['A to C substitution at nucleotide 879']    SequenceVariant
#
#   entity1_ann_id  entity1_offset entity1_length entity2_id  \
# 0              0            56.0              4    D001321
# 1              0            56.0              4    D008607
# 2              0            56.0              4    D005600
# 3             15           802.0             37    D001321
# 4             15           802.0             37    D008607
#
#                                    entity2_text                entity2_type  \
# 0                        ['autism', 'autistic']  DiseaseOrPhenotypicFeature
# 1   ['mental retardation', 'mentally retarded']  DiseaseOrPhenotypicFeature
# 2  ['Fragile X syndrome', 'fragile X syndrome']  DiseaseOrPhenotypicFeature
# 3                        ['autism', 'autistic']  DiseaseOrPhenotypicFeature
# 4   ['mental retardation', 'mentally retarded']  DiseaseOrPhenotypicFeature
#
#   entity2_ann_id  entity2_offset entity2_length is_novel  \
# 0              1            69.0              8    Novel
# 1              2            82.0             17    Novel
# 2              3           119.0             18       No
# 3              1            69.0              8    Novel
# 4              2            82.0             17    Novel
#
#                                entity_pair_type
# 0  GeneOrGeneProduct-DiseaseOrPhenotypicFeature
# 1  GeneOrGeneProduct-DiseaseOrPhenotypicFeature
# 2  GeneOrGeneProduct-DiseaseOrPhenotypicFeature
# 3    SequenceVariant-DiseaseOrPhenotypicFeature
# 4    SequenceVariant-DiseaseOrPhenotypicFeature
# (7580, 20)

# %%
unique_relations = merged_df_test['relation_type'].unique()
print("Unique relation types:", unique_relations)
print("Number of unique relation types:", len(unique_relations))
relation_counts = merged_df_test['relation_type'].value_counts()
relation_counts2 = merged_df_train['relation_type'].value_counts()
print("Relation type counts test:")
print(relation_counts)
print("Relation type counts train:")
print(relation_counts2)
num_duplicates = merged_df_test.duplicated().sum()
print("Number of duplicate rows in the DataFrame:", num_duplicates)
print(len(merged_df_test))
print(len(merged_df_train))
# Out:
# Unique relation types: ['Association' 'Positive_Correlation' 'Negative_Correlation' 'No_Relation'
#  'Cotreatment' 'Drug_Interaction' 'Bind' 'Comparison' 'Conversion']
# Number of unique relation types: 9
# Relation type counts test:
# relation_type
# No_Relation             945
# Association             636
# Positive_Correlation    326
# Negative_Correlation    172
# Cotreatment              15
# Bind                     10
# Comparison                7
# Drug_Interaction          3
# Conversion                2
# Name: count, dtype: int64
# Relation type counts train:
# relation_type
# No_Relation             3394
# Association             2193
# Positive_Correlation    1090
# Negative_Correlation     764
# Bind                      62
# Cotreatment               32
# Comparison                29
# Drug_Interaction          12
# Conversion                 4
# Name: count, dtype: int64
# Number of duplicate rows in the DataFrame: 0
# 2116
# 7580

# %% [markdown]
# ### to test a case where we want to see how less classes effect the performance we now construct a binary case of relation no relation

# %%
import pandas as pd

# Assuming your DataFrame is named 'df' and the column with labels is 'label'
merged_df_test['relation_type'] = merged_df_test['relation_type'].apply(lambda x: 'Relation' if x != 'No_Relation' else x)
relation_counts = merged_df_test['relation_type'].value_counts()
print("Relation type counts:")
print(relation_counts)
merged_df_train['relation_type'] = merged_df_train['relation_type'].apply(lambda x: 'Relation' if x != 'No_Relation' else x)
# Out:
# Relation type counts:
# relation_type
# Relation       1171
# No_Relation     945
# Name: count, dtype: int64

# %%
def generate_multiple_prompt_examples_single(df, n_prompts=3, seed=42):
    import random
    import numpy as np

    relation_types = df['relation_type'].unique()
    prompts = []

    for prompt_num in range(n_prompts):
        used_indices = set()
        examples = []
        example_num = 1
        random.seed(seed + prompt_num)
        np.random.seed(seed + prompt_num)

        for rel in relation_types:
            rel_rows = df[df['relation_type'] == rel]
            if rel_rows.empty:
                continue
            available_indices = list(set(rel_rows.index) - used_indices)
            if available_indices:
                idx = random.choice(available_indices)
            else:
                idx = random.choice(rel_rows.index)
            used_indices.add(idx)
            row = df.loc[idx]
            entities = f"Entity1: {row['entity1_text']} ({row['entity1_type']}), Entity2: {row['entity2_text']} ({row['entity2_type']})"
            example = (
                f"Example {example_num}\n"
                f"## Input:\n"
                f"Text: {row['passage_text']}\n"
                f"{entities}\n"
                f"## Output:\n"
                f"{entities}, Relation: {row['relation_type']}\n"
            )
            examples.append(example)
            example_num += 1
            if len(examples) >= 9:
                break

        prompt_text = "\n".join(examples)
        prompts.append(prompt_text)

    return prompts

# %%
def generate_multiple_prompt_examples_multi(df, n_prompts=1, seed=42, number_relations=True, relations_entitys_separately=False):
    import random
    import numpy as np

    relation_types = df['relation_type'].unique()
    prompts = []

    for prompt_num in range(n_prompts):
        used_docids = set()
        examples = []
        example_num = 1
        random.seed(seed + prompt_num)
        np.random.seed(seed + prompt_num)

        for rel in relation_types:
            rel_rows = df[df['relation_type'] == rel]
            if rel_rows.empty:
                continue
            available_indices = list(set(rel_rows.index) - used_docids)
            if available_indices:
                idx = random.choice(available_indices)
            else:
                idx = random.choice(rel_rows.index)
            doc_id = df.loc[idx, 'doc_id']
            if doc_id in used_docids:
                continue
            used_docids.add(doc_id)
            doc_rows = df[df['doc_id'] == doc_id]

            passage_text = doc_rows.iloc[0]['passage_text']
            # List all entity pairs
            if number_relations:
                entity_lines = [
                    f"{i+1}. Entity1: {row['entity1_text']} ({row['entity1_type']}), Entity2: {row['entity2_text']} ({row['entity2_type']})"
                    for i, (_, row) in enumerate(doc_rows.iterrows())
                ]
            else:
                entity_lines = [
                    f"Entity1: {row['entity1_text']} ({row['entity1_type']}), Entity2: {row['entity2_text']} ({row['entity2_type']})"
                    for _, row in doc_rows.iterrows()
                ]
            if number_relations:
                if relations_entitys_separately:
                    relation_lines = [
                        f"{i+1}. Relation: {row['relation_type']}"
                        for i, (_, row) in enumerate(doc_rows.iterrows())
                    ]
                else:
                    relation_lines = [
                        f"{i+1}. Entity1: {row['entity1_text']}, Entity2: {row['entity2_text']}, Relation: {row['relation_type']}"
                        for i, (_, row) in enumerate(doc_rows.iterrows())
                    ]
            else:
                relation_lines = [
                    f"Entity1: {row['entity1_text']}, Entity2: {row['entity2_text']}, Relation: {row['relation_type']}"
                    for _, row in doc_rows.iterrows()
                ]
            example = (
                f"Example {example_num}\n"
                #f"DocID: {doc_id}\n"
                f"## Input:\n"
                f"Text: {passage_text}\n"
                f"Entities:\n" + "\n".join(entity_lines) + "\n"
                f"## Output:\n" + "\n".join(relation_lines) + "\n"
            )
            examples.append(example)
            example_num += 1
            if len(examples) >= 9:
                break

        prompt_text = "\n".join(examples)
        prompts.append(prompt_text)

    return prompts

# %%
def fill_prompt(template_path, text, e1="", entity_type1="", e2="", entity_type2="", examples="", entity_list="", prompt_id=None):
    with open(template_path, "r", encoding="utf-8") as f:
        template = f.read()
    filled = template.format(
        text=text,
        e1=e1,
        entity_type1=entity_type1,
        e2=e2,
        entity_type2=entity_type2,
        examples=examples,
        entity_list=entity_list,
        prompt_id=prompt_id
    )
    return filled


def create_prompt_relation_df_single(df,df_2, template_path, examples=False,same_examples=False, seed=42, n_prompts=1, prompt_id=False):
    import pandas as pd
    prompts = []
    relations = []
    doc_ids = []
    runs = []
    prompt_ids = []

    prompt_id_counter = 1  # Start numbering from 1

    for run_idx in range(1, n_prompts + 1):
        if examples:
            if same_examples == True:
                example_prompts = generate_multiple_prompt_examples_single(df_2, n_prompts=1, seed=seed)
                examples_str = example_prompts[0] if example_prompts else ""
            else:
            # Generate new examples for this run with updated seed
                example_prompts = generate_multiple_prompt_examples_single(df_2, n_prompts=1, seed=seed + run_idx - 1)
            # If you want to use these as context/examples, you can pass them to fill_prompt as needed
            # Here, we assume you want to add them as an 'examples' variable in the template
                examples_str = example_prompts[0] if example_prompts else ""
        else:
            examples_str = ""

        for _, row in df.iterrows():
            if prompt_id:
                prompt = fill_prompt(
                    template_path,
                    text=row['passage_text'],
                    e1=row['entity1_text'],
                    entity_type1=row['entity1_type'],
                    e2=row['entity2_text'],
                    entity_type2=row['entity2_type'],
                    examples=examples_str,
                    prompt_id=prompt_id_counter
                )
                prompts.append(prompt)
                relations.append(row['relation_type'])
                doc_ids.append(row['doc_id'])
                runs.append(run_idx)
                prompt_ids.append(prompt_id_counter)
                prompt_id_counter += 1
            else:
                prompt = fill_prompt(
                    template_path,
                    text=row['passage_text'],
                    e1=row['entity1_text'],
                    entity_type1=row['entity1_type'],
                    e2=row['entity2_text'],
                    entity_type2=row['entity2_type'],
                    examples=examples_str,
                    prompt_id=""
                )
                prompts.append(prompt)
                relations.append(row['relation_type'])
                doc_ids.append(row['doc_id'])
                runs.append(run_idx)
                prompt_ids.append(prompt_id_counter)
                prompt_id_counter += 1

    result_df = pd.DataFrame({
        'Prompt': prompts,
        'Relation': relations,
        'DocID': doc_ids,
        'run': runs,
        'prompt_id': prompt_ids
    })
    return result_df




def prompts_df_to_json_from_runs(df, n_key="n_1"):
    """
    Converts a DataFrame with 'Prompt', 'Relation', 'DocID', and 'run' columns to the required JSON structure.
    Each run contains lists for prompts, relations, and doc_ids.
    """
    runs = {}
    for run_num in sorted(df['run'].unique()):
        run_df = df[df['run'] == run_num]
        prompts_list = run_df['Prompt'].tolist()
        relations_list = run_df['Relation'].tolist()
        doc_ids_list = run_df['DocID'].tolist()
        runs[f"run_{run_num}"] = {
            "prompts1": prompts_list,
            "relations": relations_list,
            "doc_ids": doc_ids_list
        }

    result = {n_key: runs}
    return result

def prompts_df_to_json_from_runs_multi(df, n_key="n_1"):
    """
    Converts a DataFrame with 'Prompt', 'Relation'/'Multi_Relations', 'DocID'/'Multi_DocID', and 'run' columns
    to the required JSON structure. Each run contains lists for prompts, relations, and doc_ids.
    The JSON keys will match the DataFrame column names (e.g., 'Multi_Relations' -> 'multi_relations').
    """
    runs = {}
    # Find the correct column names for relations and doc_ids
    rel_col = None
    docid_col = None
    for c in df.columns:
        if c.lower().startswith("relation"):
            rel_col = c
        if c.lower().startswith("multi_relation"):
            rel_col = c
        if c.lower() == "relations":
            rel_col = c
        if c.lower() == "multi_relations":
            rel_col = c
        if c.lower().startswith("docid"):
            docid_col = c
        if c.lower().startswith("multi_docid"):
            docid_col = c
        if c.lower() == "doc_ids":
            docid_col = c
        if c.lower() == "multi_docid":
            docid_col = c

    # Fallbacks if not found
    if rel_col is None:
        rel_col = "Relation"
    if docid_col is None:
        docid_col = "DocID"

    # Use lower-case JSON keys for consistency
    rel_json_key = rel_col.lower()
    docid_json_key = docid_col.lower()

    for run_num in sorted(df['run'].unique()):
        run_df = df[df['run'] == run_num]
        prompts_list = run_df['Prompt'].tolist()
        relations_list = run_df[rel_col].tolist()
        doc_ids_list = run_df[docid_col].tolist()
        runs[f"run_{run_num}"] = {
            "prompts1": prompts_list,
            rel_json_key: relations_list,
            docid_json_key: doc_ids_list
        }

    result = {n_key: runs}
    return result



import json
#prompt_json = prompts_df_to_json_from_runs(prompt_relation_df)
#with open("prompts_for_api.json", "w") as f:
#    json.dump(prompt_json, f, indent=2)

# %%
def create_prompt_relation_df_multi_by_docid(
    df, df_2, template_path, examples=False, same_examples=False,
    number_relations=False, relations_entitys_separately=False,
    seed=42, n_prompts=1, 
):
    import pandas as pd
    prompts = []
    relations = []
    doc_ids = []
    runs = []

    # Group by doc_id
    grouped = df.groupby('doc_id')

    for run_idx in range(1, n_prompts + 1):
        if examples:
            if same_examples:
                example_prompts = generate_multiple_prompt_examples_multi(
                    df_2, n_prompts=1, seed=seed,
                    number_relations=number_relations,
                    relations_entitys_separately=relations_entitys_separately
                )
                examples_str = example_prompts[0] if example_prompts else ""
            else:
                example_prompts = generate_multiple_prompt_examples_multi(
                    df_2, n_prompts=1, seed=seed + run_idx - 1,
                    number_relations=number_relations,
                    relations_entitys_separately=relations_entitys_separately
                )
                examples_str = example_prompts[0] if example_prompts else ""
        else:
            examples_str = ""

        for doc_id, doc_rows in grouped:
            # Build entity_lines for this doc_id
            if number_relations:
                entity_lines = [
                    f"{i+1}. Entity1: {row['entity1_text']} ({row['entity1_type']}), Entity2: {row['entity2_text']} ({row['entity2_type']})"
                    for i, (_, row) in enumerate(doc_rows.iterrows())
                ]
            else:
                entity_lines = [
                    f"Entity1: {row['entity1_text']} ({row['entity1_type']}), Entity2: {row['entity2_text']} ({row['entity2_type']})"
                    for _, row in doc_rows.iterrows()
                ]
            # Collect relations for this doc_id
            relation_list = doc_rows['relation_type'].tolist()

            # Use the first passage_text for the prompt
            passage_text = doc_rows.iloc[0]['passage_text']

            prompt = fill_prompt(
                template_path,
                text=passage_text,
                entity_list="\n".join(entity_lines),
                examples=examples_str
            )
            prompts.append(prompt)
            relations.append(relation_list)
            doc_ids.append(doc_id)
            runs.append(run_idx)

    result_df = pd.DataFrame({
        'Prompt': prompts,
        'Multi_Relations': relations,
        'Multi_DocID': doc_ids,
        'run': runs
    })
    return result_df

# %%
template_path_multi = "LLM_benchmarks/prompt_template_multi.txt"
template_path_single = "LLM_benchmarks/prompt_template_single.txt"

zero_shot_single = create_prompt_relation_df_single(merged_df_train,merged_df_test, template_path_single, examples=False,same_examples=False, seed=42, n_prompts=5)
print(zero_shot_single.head())
import json
prompt_json = prompts_df_to_json_from_runs(zero_shot_single)
with open("LLM_benchmarks/Prompts/zero_shot_single_for_api.json", "w") as f:
    json.dump(prompt_json, f, indent=2)

few_shot_single = create_prompt_relation_df_single(merged_df_train,merged_df_test, template_path_single, examples=True,same_examples=False, seed=42, n_prompts=5)
print(few_shot_single.head())
prompt_json = prompts_df_to_json_from_runs(few_shot_single)
with open("LLM_benchmarks/Prompts/few_shot_single_for_api.json", "w") as f:
    json.dump(prompt_json, f, indent=2)


# Run garbage collection to free up memory
import gc
gc.collect()

zero_shot_multi = create_prompt_relation_df_multi_by_docid(merged_df_train,merged_df_test, template_path_multi, examples=False,same_examples=False, seed=42, n_prompts=5, number_relations=True, relations_entitys_separately=False)
prompt_json = prompts_df_to_json_from_runs_multi(zero_shot_multi)
with open("LLM_benchmarks/Prompts/zero_shot_multi_for_api.json", "w") as f:
    json.dump(prompt_json, f, indent=2)

few_shot_multi = create_prompt_relation_df_multi_by_docid(merged_df_train,merged_df_test, template_path_multi, examples=True,same_examples=False, seed=42, n_prompts=5, number_relations=True, relations_entitys_separately=False)
prompt_json = prompts_df_to_json_from_runs_multi(few_shot_multi)
with open("LLM_benchmarks/Prompts/few_shot_multi_for_api.json", "w") as f:
    json.dump(prompt_json, f, indent=2) 
print(few_shot_multi.head())

import json
# Out:
#                                               Prompt              Relation  \
# 0  You are a biomedical relation extraction exper...           Association
# 1  You are a biomedical relation extraction exper...           No_Relation
# 2  You are a biomedical relation extraction exper...           No_Relation
# 3  You are a biomedical relation extraction exper...           Association
# 4  You are a biomedical relation extraction exper...  Positive_Correlation
#
#       DocID  run  prompt_id
# 0  10491763    1          1
# 1  10491763    1          2
# 2  10491763    1          3
# 3  10491763    1          4
# 4  10491763    1          5
#                                               Prompt              Relation  \
# 0  You are a biomedical relation extraction exper...           Association
# 1  You are a biomedical relation extraction exper...           No_Relation
# 2  You are a biomedical relation extraction exper...           No_Relation
# 3  You are a biomedical relation extraction exper...           Association
# 4  You are a biomedical relation extraction exper...  Positive_Correlation
#
#       DocID  run  prompt_id
# 0  10491763    1          1
# 1  10491763    1          2
# 2  10491763    1          3
# 3  10491763    1          4
# 4  10491763    1          5
#                                               Prompt  \
# 0  You are a biomedical relation extraction exper...
# 1  You are a biomedical relation extraction exper...
# 2  You are a biomedical relation extraction exper...
# 3  You are a biomedical relation extraction exper...
# 4  You are a biomedical relation extraction exper...
#
#                                      Multi_Relations Multi_DocID  run
# 0  [Association, No_Relation, No_Relation, Associ...    10491763    1
# 1                                [No_Relation, Bind]    10661407    1
# 2  [Association, No_Relation, Association, Associ...    10788334    1
# 3  [No_Relation, Negative_Correlation, Negative_C...    11009181    1
# 4  [Positive_Correlation, Positive_Correlation, P...    11054569    1

# %% [markdown]
# ## Make 1 big json for the prompts

# %%
def consolidate_prompt_jsons(json_paths, prompt_set_names, output_path):
    """
    Merge multiple prompt JSONs into one, each as a different prompt set name.
    Also adds Multi_Relations and Multi_DocID fields if present and not already in the base.
    """
    import json

    # Load all JSONs
    jsons = [json.load(open(p, "r", encoding="utf-8")) for p in json_paths]
    base = jsons[0]
    n_key = list(base.keys())[0]
    runs = base[n_key].keys()

    # For each run, add all prompt sets and Multi fields if present
    for run in runs:
        for i, js in enumerate(jsons):
            prompt_set_name = prompt_set_names[i]
            # Find the first prompt set key in this json (e.g. "prompts1")
            prompt_set_key = [k for k in js[n_key][run].keys() if k.startswith("prompts")][0]
            base[n_key][run][prompt_set_name] = js[n_key][run][prompt_set_key]
            # Add Multi_Relations if present and not already in base
            if "multi_relations" in js[n_key][run] and "multi_relations" not in base[n_key][run]:
                base[n_key][run]["multi_relations"] = js[n_key][run]["multi_relations"]
            # Add Multi_DocID if present and not already in base
            if "multi_docid" in js[n_key][run] and "multi_docid" not in base[n_key][run]:
                base[n_key][run]["multi_docid"] = js[n_key][run]["multi_docid"]

    # Save merged JSON
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(base, f, indent=2)



# Example usage:
consolidate_prompt_jsons(
    [
        "LLM_benchmarks/Prompts/zero_shot_single_for_api.json",
        "LLM_benchmarks/Prompts/few_shot_single_for_api.json",
        "LLM_benchmarks/Prompts/zero_shot_multi_for_api.json",
        "LLM_benchmarks/Prompts/few_shot_multi_for_api.json"
    ],
    ["single_zero", "single_examples", "multi_zero", "multi_examples"],
    "LLM_benchmarks/Prompts/all_prompts_consolidated_2.json"
)

consolidated_test = json.load(open("LLM_benchmarks/Prompts/all_prompts_consolidated.json", "r", encoding="utf-8"))

print(consolidated_test.keys())  # Should show the main keys like 'n_1'
# Out:
# dict_keys(['n_1'])

# %%
print(consolidated_test["n_1"]["run_1"]["multi_examples"][0])
print("##########################################################################################")
print(consolidated_test["n_1"]["run_2"]["multi_examples"][0])
# Out:
# You are a biomedical relation extraction expert following BioRED annotation guidelines.
#
# Task: Identify the relation type between two specified entities.
#
# Valid relation types (respond with EXACTLY ONE of these words):
# - Association: A general relationship exists between two entities without specifying direction or strength.
# - Positive_Correlation: As one entity increases or becomes more present, the other also increases or becomes more present.
# - Bind: Two molecules physically interact or attach to each other.
# - Negative_Correlation: As one entity increases or becomes more present, the other decreases or becomes less present.
# - Comparison: Two entities are directly compared in terms of effects, outcomes, or characteristics.
# - Conversion: One biochemical entity is transformed into another.
# - Cotreatment: Two treatments are administered together in the same experimental or clinical context.
# - Drug_Interaction: Two drugs interact to produce an altered physiological or adverse effect.
# - No_Relation: Two enteties that are not directly related according to the text.
#
# CRITICAL INSTRUCTIONS:
# 1. Only annotate EXPLICIT relations stated in the text
# 2. If entities co-occur WITHOUT a clear relationship → respond with "No_Relation"
# 3. Do NOT infer or assume relationships not explicitly stated
# 4. When uncertain → respond with "No_Relation"
# Example 1
# ## Input:
# Text: Two novel mutations in the MEN1 gene in subjects with multiple endocrine neoplasia-1. Multiple endocrine neoplasia type 1 (MEN1) is characterized by parathyroid, enteropancreatic endocrine and pituitary adenomas as well as germline mutation of the MEN1 gene. We describe 2 families with MEN1 with novel mutations in the MEN1 gene. One family was of Turkish origin, and the index patient had primary hyperparathyroidism (PHPT) plus a prolactinoma; three relatives had PHPT only. The index patient in the second family was a 46-yr-old woman of Chinese origin living in Taiwan. This patient presented with a complaint of epigastric pain and watery diarrhea over the past 3 months, and had undergone subtotal parathyroidectomy and enucleation of pancreatic islet cell tumor about 10 yr before. There was also a prolactinoma. Sequence analysis of the MEN1 gene from leukocyte genomic DNA revealed heterozygous mutations in both probands. The Turkish patient and her affected relatives all had a heterozygous A to G transition at codon 557 (AAG-->GAG) of exon 10 of MEN1 that results in a replacement of lysine by glutamic acid. The Chinese index patient and one of her siblings had a heterozygous mutation at codon 418 of exon 9 (GAC-->TAT) that results in a substitution of aspartic acid by tyrosine. In conclusion, we have identified 2 novel missense mutations in the MEN1 gene.
# Entities:
# 1. Entity1: ['MEN1'] (GeneOrGeneProduct), Entity2: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'] (DiseaseOrPhenotypicFeature)
# 2. Entity1: ['MEN1'] (GeneOrGeneProduct), Entity2: ['PHPT', 'primary hyperparathyroidism'] (DiseaseOrPhenotypicFeature)
# 3. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'] (DiseaseOrPhenotypicFeature), Entity2: ['A to G transition at codon 557 (AAG-->GAG)'] (SequenceVariant)
# 4. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'] (DiseaseOrPhenotypicFeature), Entity2: ['lysine by glutamic acid'] (SequenceVariant)
# 5. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'] (DiseaseOrPhenotypicFeature), Entity2: ['mutation at codon 418 of exon 9 (GAC-->TAT)'] (SequenceVariant)
# 6. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'] (DiseaseOrPhenotypicFeature), Entity2: ['aspartic acid by tyrosine'] (SequenceVariant)
# 7. Entity1: ['prolactinoma'] (DiseaseOrPhenotypicFeature), Entity2: ['aspartic acid by tyrosine'] (SequenceVariant)
# 8. Entity1: ['pain'] (DiseaseOrPhenotypicFeature), Entity2: ['MEN1'] (GeneOrGeneProduct)
# 9. Entity1: ['pain'] (DiseaseOrPhenotypicFeature), Entity2: ['A to G transition at codon 557 (AAG-->GAG)'] (SequenceVariant)
# 10. Entity1: ['pancreatic islet cell tumor'] (DiseaseOrPhenotypicFeature), Entity2: ['A to G transition at codon 557 (AAG-->GAG)'] (SequenceVariant)
# ## Output:
# 1. Entity1: ['MEN1'], Entity2: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'], Relation: Association
# 2. Entity1: ['MEN1'], Entity2: ['PHPT', 'primary hyperparathyroidism'], Relation: No_Relation
# 3. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'], Entity2: ['A to G transition at codon 557 (AAG-->GAG)'], Relation: Association
# 4. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'], Entity2: ['lysine by glutamic acid'], Relation: Association
# 5. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'], Entity2: ['mutation at codon 418 of exon 9 (GAC-->TAT)'], Relation: Association
# 6. Entity1: ['MEN1', 'Multiple endocrine neoplasia type 1', 'multiple endocrine neoplasia-1'], Entity2: ['aspartic acid by tyrosine'], Relation: Association
# 7. Entity1: ['prolactinoma'], Entity2: ['aspartic acid by tyrosine'], Relation: No_Relation
# 8. Entity1: ['pain'], Entity2: ['MEN1'], Relation: No_Relation
# 9. Entity1: ['pain'], Entity2: ['A to G transition at codon 557 (AAG-->GAG)'], Relation: No_Relation
# 10. Entity1: ['pancreatic islet cell tumor'], Entity2: ['A to G transition at codon 557 (AAG-->GAG)'], Relation: No_Relation
#
# Example 2
# ## Input:
# Text: Mutation screening of the GUCA1B gene in patients with autosomal dominant cone and cone rod dystrophy. Background: Heterozygous mutations in GUCA1A (MIM # 600364) have been identified to cause autosomal dominantly inherited cone dystrophy, cone rod dystrophy and macular dystrophy. However, the role of GUCA1B gene mutations in inherited retinal disease has been controversial. We therefore performed a mutation analysis of the GUCA1B gene in a clinically well characterized group of patients of European and North-American geographical origin with autosomal dominantly inherited cone dystrophy and cone rod dystrophy. Material and Methods: Twenty-four unrelated patients diagnosed with cone dystrophy or cone rod dystrophy according to standard diagnostic criteria and a family history consistent with an autosomal dominant mode of inheritance were included in the study. Mutation analysis of all coding exons of the GUCA1B gene was performed by polymerase chain reaction amplification of genomic DNA and subsequent DNA sequencing. Results: Three different sequence variants, c.-17T>C, c.171T>C, c.465G>T were identified. The sequence variant c.465G>T encodes a conservative amino acid substitution, p.Glu155Asp, located in EF-hand 4, the calcium binding site of GCAP2 protein. All sequence variants were previously reported in healthy subjects. Conclusion: The absence of clearly pathogenic mutations in the selected patient group suggests that the GUCA1B gene is a minor cause for retinal degenerations in Europeans or North-Americans.
# Entities:
# 1. Entity1: ['GCAP2', 'GUCA1B'] (GeneOrGeneProduct), Entity2: ['cone and cone rod dystrophy', 'cone dystrophy'] (DiseaseOrPhenotypicFeature)
# 2. Entity1: ['GCAP2', 'GUCA1B'] (GeneOrGeneProduct), Entity2: ['cone and cone rod dystrophy', 'cone rod dystrophy'] (DiseaseOrPhenotypicFeature)
# 3. Entity1: ['GCAP2', 'GUCA1B'] (GeneOrGeneProduct), Entity2: ['retinal disease'] (DiseaseOrPhenotypicFeature)
# 4. Entity1: ['GCAP2', 'GUCA1B'] (GeneOrGeneProduct), Entity2: ['retinal degenerations'] (DiseaseOrPhenotypicFeature)
# 5. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['GUCA1A'] (GeneOrGeneProduct)
# 6. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['GUCA1A'] (GeneOrGeneProduct)
# 7. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['c.-17T>C'] (SequenceVariant)
# 8. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['c.-17T>C'] (SequenceVariant)
# 9. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['c.171T>C'] (SequenceVariant)
# 10. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['c.171T>C'] (SequenceVariant)
# 11. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['c.465G>T', 'p.Glu155Asp'] (SequenceVariant)
# 12. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['c.465G>T', 'p.Glu155Asp'] (SequenceVariant)
# 13. Entity1: ['macular dystrophy'] (DiseaseOrPhenotypicFeature), Entity2: ['GUCA1A'] (GeneOrGeneProduct)
# 14. Entity1: ['c.171T>C'] (SequenceVariant), Entity2: ['retinal degenerations'] (DiseaseOrPhenotypicFeature)
# 15. Entity1: ['c.465G>T', 'p.Glu155Asp'] (SequenceVariant), Entity2: ['calcium'] (ChemicalEntity)
# 16. Entity1: ['c.465G>T', 'p.Glu155Asp'] (SequenceVariant), Entity2: ['retinal degenerations'] (DiseaseOrPhenotypicFeature)
# 17. Entity1: ['calcium'] (ChemicalEntity), Entity2: ['GCAP2', 'GUCA1B'] (GeneOrGeneProduct)
# ## Output:
# 1. Entity1: ['GCAP2', 'GUCA1B'], Entity2: ['cone and cone rod dystrophy', 'cone dystrophy'], Relation: Association
# 2. Entity1: ['GCAP2', 'GUCA1B'], Entity2: ['cone and cone rod dystrophy', 'cone rod dystrophy'], Relation: Association
# 3. Entity1: ['GCAP2', 'GUCA1B'], Entity2: ['retinal disease'], Relation: Association
# 4. Entity1: ['GCAP2', 'GUCA1B'], Entity2: ['retinal degenerations'], Relation: Association
# 5. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'], Entity2: ['GUCA1A'], Relation: Association
# 6. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'], Entity2: ['GUCA1A'], Relation: Association
# 7. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'], Entity2: ['c.-17T>C'], Relation: Positive_Correlation
# 8. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'], Entity2: ['c.-17T>C'], Relation: Positive_Correlation
# 9. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'], Entity2: ['c.171T>C'], Relation: Positive_Correlation
# 10. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'], Entity2: ['c.171T>C'], Relation: Positive_Correlation
# 11. Entity1: ['cone and cone rod dystrophy', 'cone dystrophy'], Entity2: ['c.465G>T', 'p.Glu155Asp'], Relation: Positive_Correlation
# 12. Entity1: ['cone and cone rod dystrophy', 'cone rod dystrophy'], Entity2: ['c.465G>T', 'p.Glu155Asp'], Relation: Positive_Correlation
# 13. Entity1: ['macular dystrophy'], Entity2: ['GUCA1A'], Relation: Association
# 14. Entity1: ['c.171T>C'], Entity2: ['retinal degenerations'], Relation: No_Relation
# 15. Entity1: ['c.465G>T', 'p.Glu155Asp'], Entity2: ['calcium'], Relation: Association
# 16. Entity1: ['c.465G>T', 'p.Glu155Asp'], Entity2: ['retinal degenerations'], Relation: No_Relation
# 17. Entity1: ['calcium'], Entity2: ['GCAP2', 'GUCA1B'], Relation: Bind
#
# Example 3
# ## Input:
# Text: Genetic polymorphisms in the carbonyl reductase 3 gene CBR3 and the NAD(P)H:quinone oxidoreductase 1 gene NQO1 in patients who developed anthracycline-related congestive heart failure after childhood cancer. BACKGROUND: Exposure to anthracyclines as part of cancer therapy has been associated with the development of congestive heart failure (CHF). The potential role of genetic risk factors in anthracycline-related CHF remains to be defined. Thus, in this study, the authors examined whether common polymorphisms in candidate genes involved in the pharmacodynamics of anthracyclines (in particular, the nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1 gene NQO1 and the carbonyl reductase 3 gene CBR3) had an impact on the risk of anthracycline-related CHF. METHODS: A nested case-control study was conducted within a cohort of 1979 patients enrolled in the Childhood Cancer Survivor Study who received treatment with anthracyclines and had available DNA. Thirty patients with CHF (cases) and 115 matched controls were genotyped for polymorphisms in NQO1 (NQO1*2) and CBR3 (the CBR3 valine [V] to methionine [M] substitution at position 244 [V244M]). Enzyme activity assays with recombinant CBR3 isoforms (CBR3 V244 and CBR3 M244) and the anthracycline substrate doxorubicin were used to investigate the functional impact of the CBR3 V244M polymorphism. RESULTS: Multivariate analyses adjusted for sex and primary disease recurrence were used to test for associations between the candidate genetic polymorphisms (NQO1*2 and CBR3 V244M) and the risk of CHF. Analyses indicated no association between the NQO1*2 polymorphism and the risk of anthracycline-related CHF (odds ratio [OR], 1.04; P=.97). There was a trend toward an association between the CBR3 V244M polymorphism and the risk of CHF (OR, 8.16; P=.056 for G/G vs A/A; OR, 5.44; P=.092 for G/A vs A/A). In line, recombinant CBR3 V244 (G allele) synthesized 2.6-fold more cardiotoxic doxorubicinol per unit of time than CBR3 M244 (A allele; CBR3 V244 [8.26+/-3.57 nmol/hour.mg] vs CBR3 M244 [3.22+/-0.67 nmol/hour.mg]; P=.01). CONCLUSIONS: The functional CBR3 V244M polymorphism may have an impact on the risk of anthracycline-related CHF among childhood cancer survivors by modulating the intracardiac formation of cardiotoxic anthracycline alcohol metabolites. Larger confirmatory case-control studies are warranted.
# Entities:
# 1. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct)
# 2. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct)
# 3. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity)
# 4. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['CHF', 'congestive heart failure'] (DiseaseOrPhenotypicFeature)
# 5. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['cancer'] (DiseaseOrPhenotypicFeature)
# 6. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['doxorubicin'] (ChemicalEntity)
# 7. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['cardiotoxic'] (DiseaseOrPhenotypicFeature)
# 8. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['doxorubicinol'] (ChemicalEntity)
# 9. Entity1: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct), Entity2: ['anthracycline alcohol'] (ChemicalEntity)
# 10. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct), Entity2: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct)
# 11. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct), Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct)
# 12. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct), Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity)
# 13. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct), Entity2: ['CHF', 'congestive heart failure'] (DiseaseOrPhenotypicFeature)
# 14. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity), Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct)
# 15. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity), Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity)
# 16. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity), Entity2: ['CHF', 'congestive heart failure'] (DiseaseOrPhenotypicFeature)
# 17. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity), Entity2: ['cancer'] (DiseaseOrPhenotypicFeature)
# 18. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity), Entity2: ['cardiotoxic'] (DiseaseOrPhenotypicFeature)
# 19. Entity1: ['CHF', 'congestive heart failure'] (DiseaseOrPhenotypicFeature), Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'] (GeneOrGeneProduct)
# 20. Entity1: ['CHF', 'congestive heart failure'] (DiseaseOrPhenotypicFeature), Entity2: ['anthracycline alcohol'] (ChemicalEntity)
# 21. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant), Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'] (ChemicalEntity)
# 22. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant), Entity2: ['CHF', 'congestive heart failure'] (DiseaseOrPhenotypicFeature)
# 23. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant), Entity2: ['cancer'] (DiseaseOrPhenotypicFeature)
# 24. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant), Entity2: ['cardiotoxic'] (DiseaseOrPhenotypicFeature)
# 25. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant), Entity2: ['doxorubicinol'] (ChemicalEntity)
# 26. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant), Entity2: ['anthracycline alcohol'] (ChemicalEntity)
# 27. Entity1: ['doxorubicin'] (ChemicalEntity), Entity2: ['CBR3', 'carbonyl reductase 3'] (GeneOrGeneProduct)
# 28. Entity1: ['cardiotoxic'] (DiseaseOrPhenotypicFeature), Entity2: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'] (SequenceVariant)
# 29. Entity1: ['cardiotoxic'] (DiseaseOrPhenotypicFeature), Entity2: ['doxorubicinol'] (ChemicalEntity)
# 30. Entity1: ['doxorubicinol'] (ChemicalEntity), Entity2: ['cancer'] (DiseaseOrPhenotypicFeature)
# 31. Entity1: ['anthracycline alcohol'] (ChemicalEntity), Entity2: ['cardiotoxic'] (DiseaseOrPhenotypicFeature)
# ## Output:
# 1. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['CBR3', 'carbonyl reductase 3'], Relation: No_Relation
# 2. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Relation: No_Relation
# 3. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Relation: Association
# 4. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['CHF', 'congestive heart failure'], Relation: Association
# 5. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['cancer'], Relation: No_Relation
# 6. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['doxorubicin'], Relation: No_Relation
# 7. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['cardiotoxic'], Relation: Association
# 8. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['doxorubicinol'], Relation: Association
# 9. Entity1: ['CBR3', 'carbonyl reductase 3'], Entity2: ['anthracycline alcohol'], Relation: Association
# 10. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Entity2: ['CBR3', 'carbonyl reductase 3'], Relation: No_Relation
# 11. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Relation: No_Relation
# 12. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Relation: No_Relation
# 13. Entity1: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Entity2: ['CHF', 'congestive heart failure'], Relation: No_Relation
# 14. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Relation: No_Relation
# 15. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Relation: No_Relation
# 16. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Entity2: ['CHF', 'congestive heart failure'], Relation: Positive_Correlation
# 17. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Entity2: ['cancer'], Relation: Negative_Correlation
# 18. Entity1: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Entity2: ['cardiotoxic'], Relation: Positive_Correlation
# 19. Entity1: ['CHF', 'congestive heart failure'], Entity2: ['NAD(P)H:quinone oxidoreductase 1', 'NQO1', 'nicotinamide adenine dinucleotide phosphate:quinone oxidoreductase 1'], Relation: No_Relation
# 20. Entity1: ['CHF', 'congestive heart failure'], Entity2: ['anthracycline alcohol'], Relation: Association
# 21. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Entity2: ['anthracycline', 'anthracycline alcohol', 'anthracyclines'], Relation: Association
# 22. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Entity2: ['CHF', 'congestive heart failure'], Relation: Positive_Correlation
# 23. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Entity2: ['cancer'], Relation: No_Relation
# 24. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Entity2: ['cardiotoxic'], Relation: No_Relation
# 25. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Entity2: ['doxorubicinol'], Relation: Association
# 26. Entity1: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Entity2: ['anthracycline alcohol'], Relation: Association
# 27. Entity1: ['doxorubicin'], Entity2: ['CBR3', 'carbonyl reductase 3'], Relation: No_Relation
# 28. Entity1: ['cardiotoxic'], Entity2: ['M244', 'V244', 'V244M', 'valine [V] to methionine [M] substitution at position 244'], Relation: No_Relation
# 29. Entity1: ['cardiotoxic'], Entity2: ['doxorubicinol'], Relation: Positive_Correlation
# 30. Entity1: ['doxorubicinol'], Entity2: ['cancer'], Relation: No_Relation
# 31. Entity1: ['anthracycline alcohol'], Entity2: ['cardiotoxic'], Relation: Positive_Correlation
#
# Example 4
# ## Input:
# Text: Association between an endoglin gene polymorphism and systemic sclerosis-related pulmonary arterial hypertension. Systemic sclerosis (SSc) is a connective tissue disorder characterized by early generalized microangiopathy with disturbed angiogenesis. Endoglin gene (ENG) encodes a transmembrane glycoprotein which acts as an accessory receptor for the transforming growth factor-beta (TGF-beta) superfamily, and is crucial for maintaining vascular integrity. A 6-base insertion in intron 7 (6bINS) of ENG has been reported to be associated with microvascular disturbance. OBJECTIVES: Our objective was to investigate the relationship between 6bINS and the vascular complication pulmonary arterial hypertension (PAH) in SSc in a French Caucasian population. METHODS: Two hundred eighty SSc cases containing 29/280 having PAH diagnosed by catheterism were compared with 140 patients with osteoarthritis. Genotyping was performed by polymerase-chain-reaction-based fluorescence and direct sequencing of genomic DNA. RESULTS: The polymorphism was in Hardy-Weinberg equilibrium. We observed a significant lower frequency of 6bINS allele in SSc patients with associated PAH compared with controls [10.3 vs 23.9%, P = 0.01; odds ratio (OR) 0.37, 95% confidence interval (CI) 0.15-0.89], and a trend in comparison with SSc patients without PAH (10.3 vs 20.3%, P = 0.05; OR: 0.45, 95% CI: 0.19-1.08). Genotypes carrying allele 6bINS were also less frequent in SSc patients with PAH than in controls (20.7 vs 42.9%, P = 0.02). CONCLUSIONS: Thus the frequency of 6bINS differs between SSc patients with or without PAH, suggesting the implication of ENG in this devastating vascular complication of SSc.
# Entities:
# 1. Entity1: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct), Entity2: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct)
# 2. Entity1: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct), Entity2: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'] (DiseaseOrPhenotypicFeature)
# 3. Entity1: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct), Entity2: ['TGF-beta', 'transforming growth factor-beta'] (GeneOrGeneProduct)
# 4. Entity1: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct), Entity2: ['vascular complication'] (DiseaseOrPhenotypicFeature)
# 5. Entity1: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct), Entity2: ['osteoarthritis'] (DiseaseOrPhenotypicFeature)
# 6. Entity1: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'] (DiseaseOrPhenotypicFeature), Entity2: ['glycoprotein'] (GeneOrGeneProduct)
# 7. Entity1: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'] (DiseaseOrPhenotypicFeature), Entity2: ['TGF-beta', 'transforming growth factor-beta'] (GeneOrGeneProduct)
# 8. Entity1: ['PAH', 'pulmonary arterial hypertension'] (DiseaseOrPhenotypicFeature), Entity2: ['ENG', 'Endoglin', 'endoglin'] (GeneOrGeneProduct)
# 9. Entity1: ['microangiopathy'] (DiseaseOrPhenotypicFeature), Entity2: ['6-base insertion', '6bINS'] (SequenceVariant)
# 10. Entity1: ['glycoprotein'] (GeneOrGeneProduct), Entity2: ['PAH', 'pulmonary arterial hypertension'] (DiseaseOrPhenotypicFeature)
# 11. Entity1: ['TGF-beta', 'transforming growth factor-beta'] (GeneOrGeneProduct), Entity2: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'] (DiseaseOrPhenotypicFeature)
# 12. Entity1: ['TGF-beta', 'transforming growth factor-beta'] (GeneOrGeneProduct), Entity2: ['PAH', 'pulmonary arterial hypertension'] (DiseaseOrPhenotypicFeature)
# 13. Entity1: ['TGF-beta', 'transforming growth factor-beta'] (GeneOrGeneProduct), Entity2: ['osteoarthritis'] (DiseaseOrPhenotypicFeature)
# 14. Entity1: ['6-base insertion', '6bINS'] (SequenceVariant), Entity2: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'] (DiseaseOrPhenotypicFeature)
# 15. Entity1: ['6-base insertion', '6bINS'] (SequenceVariant), Entity2: ['PAH', 'pulmonary arterial hypertension'] (DiseaseOrPhenotypicFeature)
# 16. Entity1: ['6-base insertion', '6bINS'] (SequenceVariant), Entity2: ['vascular complication'] (DiseaseOrPhenotypicFeature)
# 17. Entity1: ['6-base insertion', '6bINS'] (SequenceVariant), Entity2: ['osteoarthritis'] (DiseaseOrPhenotypicFeature)
# 18. Entity1: ['osteoarthritis'] (DiseaseOrPhenotypicFeature), Entity2: ['6-base insertion', '6bINS'] (SequenceVariant)
# ## Output:
# 1. Entity1: ['ENG', 'Endoglin', 'endoglin'], Entity2: ['ENG', 'Endoglin', 'endoglin'], Relation: No_Relation
# 2. Entity1: ['ENG', 'Endoglin', 'endoglin'], Entity2: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'], Relation: Association
# 3. Entity1: ['ENG', 'Endoglin', 'endoglin'], Entity2: ['TGF-beta', 'transforming growth factor-beta'], Relation: Bind
# 4. Entity1: ['ENG', 'Endoglin', 'endoglin'], Entity2: ['vascular complication'], Relation: Association
# 5. Entity1: ['ENG', 'Endoglin', 'endoglin'], Entity2: ['osteoarthritis'], Relation: No_Relation
# 6. Entity1: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'], Entity2: ['glycoprotein'], Relation: No_Relation
# 7. Entity1: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'], Entity2: ['TGF-beta', 'transforming growth factor-beta'], Relation: No_Relation
# 8. Entity1: ['PAH', 'pulmonary arterial hypertension'], Entity2: ['ENG', 'Endoglin', 'endoglin'], Relation: Association
# 9. Entity1: ['microangiopathy'], Entity2: ['6-base insertion', '6bINS'], Relation: No_Relation
# 10. Entity1: ['glycoprotein'], Entity2: ['PAH', 'pulmonary arterial hypertension'], Relation: No_Relation
# 11. Entity1: ['TGF-beta', 'transforming growth factor-beta'], Entity2: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'], Relation: No_Relation
# 12. Entity1: ['TGF-beta', 'transforming growth factor-beta'], Entity2: ['PAH', 'pulmonary arterial hypertension'], Relation: No_Relation
# 13. Entity1: ['TGF-beta', 'transforming growth factor-beta'], Entity2: ['osteoarthritis'], Relation: No_Relation
# 14. Entity1: ['6-base insertion', '6bINS'], Entity2: ['SSc', 'Systemic sclerosis', 'systemic sclerosis'], Relation: Association
# 15. Entity1: ['6-base insertion', '6bINS'], Entity2: ['PAH', 'pulmonary arterial hypertension'], Relation: Negative_Correlation
# 16. Entity1: ['6-base insertion', '6bINS'], Entity2: ['vascular complication'], Relation: Association
# 17. Entity1: ['6-base insertion', '6bINS'], Entity2: ['osteoarthritis'], Relation: No_Relation
# 18. Entity1: ['osteoarthritis'], Entity2: ['6-base insertion', '6bINS'], Relation: No_Relation
#
# Example 5
# ## Input:
# Text: Organophosphate-induced convulsions and prevention of neuropathological damages. Such organophosphorus (OP) compounds as diisopropylfluorophosphate (DFP), sarin and soman are potent inhibitors of acetylcholinesterases (AChEs) and butyrylcholinesterases (BChEs). The acute toxicity of OPs is the result of their irreversible binding with AChEs in the central nervous system (CNS), which elevates acetylcholine (ACh) levels. The protective action of subcutaneously (SC) administered antidotes or their combinations in DFP (2.0 mg/kg BW) intoxication was studied in 9-10-weeks-old Han-Wistar male rats. The rats received AChE reactivator pralidoxime-2-chloride (2PAM) (30.0 mg/kg BW), anticonvulsant diazepam (2.0 mg/kg BW), A(1)-adenosine receptor agonist N(6)-cyclopentyl adenosine (CPA) (2.0 mg/kg BW), NMDA-receptor antagonist dizocilpine maleate (+-MK801 hydrogen maleate) (2.0 mg/kg BW) or their combinations with cholinolytic drug atropine sulfate (50.0 mg/kg BW) immediately or 30 min after the single SC injection of DFP. The control rats received atropine sulfate, but also saline and olive oil instead of other antidotes and DFP, respectively. All rats were terminated either 24 h or 3 weeks after the DFP injection. The rats treated with DFP-atropine showed severe typical OP-induced toxicity signs. When CPA, diazepam or 2PAM was given immediately after DFP-atropine, these treatments prevented, delayed or shortened the occurrence of serious signs of poisoning. Atropine-MK801 did not offer any additional protection against DFP toxicity. In conclusion, CPA, diazepam and 2PAM in combination with atropine prevented the occurrence of serious signs of poisoning and thus reduced the toxicity of DFP in rat.
# Entities:
# 1. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['convulsions'] (DiseaseOrPhenotypicFeature)
# 2. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['neuropathological damages'] (DiseaseOrPhenotypicFeature)
# 3. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 4. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 5. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 6. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['ACh', 'acetylcholine'] (ChemicalEntity)
# 7. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 8. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['NMDA-receptor'] (GeneOrGeneProduct)
# 9. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 10. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 11. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 12. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 13. Entity1: ['sarin'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 14. Entity1: ['sarin'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 15. Entity1: ['soman'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 16. Entity1: ['soman'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 17. Entity1: ['soman'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 18. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 19. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['ACh', 'acetylcholine'] (ChemicalEntity)
# 20. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity)
# 21. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['diazepam'] (ChemicalEntity)
# 22. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 23. Entity1: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct), Entity2: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity)
# 24. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 25. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 26. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity)
# 27. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 28. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 29. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['olive oil'] (ChemicalEntity)
# 30. Entity1: ['ACh', 'acetylcholine'] (ChemicalEntity), Entity2: ['diazepam'] (ChemicalEntity)
# 31. Entity1: ['ACh', 'acetylcholine'] (ChemicalEntity), Entity2: ['NMDA-receptor'] (GeneOrGeneProduct)
# 32. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 33. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['diazepam'] (ChemicalEntity)
# 34. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 35. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 36. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 37. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 38. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 39. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 40. Entity1: ['A(1)-adenosine receptor'] (GeneOrGeneProduct), Entity2: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity)
# 41. Entity1: ['A(1)-adenosine receptor'] (GeneOrGeneProduct), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 42. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 43. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['diazepam'] (ChemicalEntity)
# 44. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 45. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 46. Entity1: ['NMDA-receptor'] (GeneOrGeneProduct), Entity2: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity)
# 47. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 48. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 49. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity), Entity2: ['olive oil'] (ChemicalEntity)
# 50. Entity1: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 51. Entity1: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 52. Entity1: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 53. Entity1: ['poisoning'] (DiseaseOrPhenotypicFeature), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 54. Entity1: ['poisoning'] (DiseaseOrPhenotypicFeature), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# ## Output:
# 1. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['convulsions'], Relation: Positive_Correlation
# 2. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['neuropathological damages'], Relation: Association
# 3. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Negative_Correlation
# 4. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Negative_Correlation
# 5. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['toxicity'], Relation: No_Relation
# 6. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['ACh', 'acetylcholine'], Relation: Association
# 7. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: No_Relation
# 8. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['NMDA-receptor'], Relation: No_Relation
# 9. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 10. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Negative_Correlation
# 11. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Negative_Correlation
# 12. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['poisoning'], Relation: No_Relation
# 13. Entity1: ['sarin'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Negative_Correlation
# 14. Entity1: ['sarin'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Negative_Correlation
# 15. Entity1: ['soman'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Negative_Correlation
# 16. Entity1: ['soman'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Negative_Correlation
# 17. Entity1: ['soman'], Entity2: ['toxicity'], Relation: No_Relation
# 18. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: No_Relation
# 19. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['ACh', 'acetylcholine'], Relation: Association
# 20. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['2PAM', 'pralidoxime-2-chloride'], Relation: Positive_Correlation
# 21. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['diazepam'], Relation: No_Relation
# 22. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: No_Relation
# 23. Entity1: ['BChEs', 'butyrylcholinesterases'], Entity2: ['2PAM', 'pralidoxime-2-chloride'], Relation: No_Relation
# 24. Entity1: ['toxicity'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 25. Entity1: ['toxicity'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: No_Relation
# 26. Entity1: ['toxicity'], Entity2: ['2PAM', 'pralidoxime-2-chloride'], Relation: No_Relation
# 27. Entity1: ['toxicity'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: No_Relation
# 28. Entity1: ['toxicity'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: No_Relation
# 29. Entity1: ['toxicity'], Entity2: ['olive oil'], Relation: No_Relation
# 30. Entity1: ['ACh', 'acetylcholine'], Entity2: ['diazepam'], Relation: No_Relation
# 31. Entity1: ['ACh', 'acetylcholine'], Entity2: ['NMDA-receptor'], Relation: No_Relation
# 32. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Negative_Correlation
# 33. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['diazepam'], Relation: Cotreatment
# 34. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: Cotreatment
# 35. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: Cotreatment
# 36. Entity1: ['diazepam'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Negative_Correlation
# 37. Entity1: ['diazepam'], Entity2: ['toxicity'], Relation: No_Relation
# 38. Entity1: ['diazepam'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: Cotreatment
# 39. Entity1: ['diazepam'], Entity2: ['poisoning'], Relation: No_Relation
# 40. Entity1: ['A(1)-adenosine receptor'], Entity2: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Relation: No_Relation
# 41. Entity1: ['A(1)-adenosine receptor'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: Positive_Correlation
# 42. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Negative_Correlation
# 43. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['diazepam'], Relation: Cotreatment
# 44. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: Cotreatment
# 45. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['poisoning'], Relation: No_Relation
# 46. Entity1: ['NMDA-receptor'], Entity2: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Relation: Negative_Correlation
# 47. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 48. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Entity2: ['toxicity'], Relation: No_Relation
# 49. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Entity2: ['olive oil'], Relation: No_Relation
# 50. Entity1: ['Atropine', 'atropine', 'atropine sulfate'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Negative_Correlation
# 51. Entity1: ['Atropine', 'atropine', 'atropine sulfate'], Entity2: ['toxicity'], Relation: No_Relation
# 52. Entity1: ['Atropine', 'atropine', 'atropine sulfate'], Entity2: ['poisoning'], Relation: No_Relation
# 53. Entity1: ['poisoning'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 54. Entity1: ['poisoning'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: No_Relation
#
# Example 6
# ## Input:
# Text: Pheochromocytoma unmasked by amisulpride and tiapride. OBJECTIVE: To describe the unmasking of pheochromocytoma in a patient treated with amisulpride and tiapride. CASE SUMMARY: A 42-year-old white man developed acute hypertension with severe headache and vomiting 2 hours after the first doses of amisulpride 100 mg and tiapride 100 mg. Both drugs were immediately discontinued, and the patient recovered after subsequent nicardipine and verapamil treatment. Abdominal ultrasound showed an adrenal mass, and postoperative histologic examination confirmed the diagnosis of pheochromocytoma. DISCUSSION: Drug-induced symptoms of pheochromocytoma are often associated with the use of substituted benzamide drugs, but the underlying mechanism is unknown. In our case, use of the Naranjo probability scale indicated a possible relationship between the hypertensive crisis and amisulpride and tiapride therapy. CONCLUSIONS: As of March 24, 2005, this is the first reported case of amisulpride- and tiapride-induced hypertensive crisis in a patient with pheochromocytoma. Physicians and other healthcare professionals should be aware of this potential adverse effect of tiapride and amisulpride.
# Entities:
# 1. Entity1: ['Pheochromocytoma', 'pheochromocytoma'] (DiseaseOrPhenotypicFeature), Entity2: ['amisulpride'] (ChemicalEntity)
# 2. Entity1: ['Pheochromocytoma', 'pheochromocytoma'] (DiseaseOrPhenotypicFeature), Entity2: ['tiapride'] (ChemicalEntity)
# 3. Entity1: ['Pheochromocytoma', 'pheochromocytoma'] (DiseaseOrPhenotypicFeature), Entity2: ['verapamil'] (ChemicalEntity)
# 4. Entity1: ['amisulpride'] (ChemicalEntity), Entity2: ['tiapride'] (ChemicalEntity)
# 5. Entity1: ['amisulpride'] (ChemicalEntity), Entity2: ['nicardipine'] (ChemicalEntity)
# 6. Entity1: ['tiapride'] (ChemicalEntity), Entity2: ['benzamide drugs'] (ChemicalEntity)
# 7. Entity1: ['hypertension', 'hypertensive'] (DiseaseOrPhenotypicFeature), Entity2: ['amisulpride'] (ChemicalEntity)
# 8. Entity1: ['hypertension', 'hypertensive'] (DiseaseOrPhenotypicFeature), Entity2: ['tiapride'] (ChemicalEntity)
# 9. Entity1: ['headache'] (DiseaseOrPhenotypicFeature), Entity2: ['amisulpride'] (ChemicalEntity)
# 10. Entity1: ['headache'] (DiseaseOrPhenotypicFeature), Entity2: ['tiapride'] (ChemicalEntity)
# 11. Entity1: ['headache'] (DiseaseOrPhenotypicFeature), Entity2: ['benzamide drugs'] (ChemicalEntity)
# 12. Entity1: ['vomiting'] (DiseaseOrPhenotypicFeature), Entity2: ['amisulpride'] (ChemicalEntity)
# 13. Entity1: ['vomiting'] (DiseaseOrPhenotypicFeature), Entity2: ['tiapride'] (ChemicalEntity)
# 14. Entity1: ['nicardipine'] (ChemicalEntity), Entity2: ['Pheochromocytoma', 'pheochromocytoma'] (DiseaseOrPhenotypicFeature)
# 15. Entity1: ['nicardipine'] (ChemicalEntity), Entity2: ['tiapride'] (ChemicalEntity)
# 16. Entity1: ['nicardipine'] (ChemicalEntity), Entity2: ['hypertension', 'hypertensive'] (DiseaseOrPhenotypicFeature)
# 17. Entity1: ['nicardipine'] (ChemicalEntity), Entity2: ['headache'] (DiseaseOrPhenotypicFeature)
# 18. Entity1: ['nicardipine'] (ChemicalEntity), Entity2: ['vomiting'] (DiseaseOrPhenotypicFeature)
# 19. Entity1: ['nicardipine'] (ChemicalEntity), Entity2: ['verapamil'] (ChemicalEntity)
# 20. Entity1: ['verapamil'] (ChemicalEntity), Entity2: ['hypertension', 'hypertensive'] (DiseaseOrPhenotypicFeature)
# 21. Entity1: ['verapamil'] (ChemicalEntity), Entity2: ['headache'] (DiseaseOrPhenotypicFeature)
# 22. Entity1: ['verapamil'] (ChemicalEntity), Entity2: ['vomiting'] (DiseaseOrPhenotypicFeature)
# 23. Entity1: ['benzamide drugs'] (ChemicalEntity), Entity2: ['Pheochromocytoma', 'pheochromocytoma'] (DiseaseOrPhenotypicFeature)
# ## Output:
# 1. Entity1: ['Pheochromocytoma', 'pheochromocytoma'], Entity2: ['amisulpride'], Relation: Association
# 2. Entity1: ['Pheochromocytoma', 'pheochromocytoma'], Entity2: ['tiapride'], Relation: Association
# ...
# 13. Entity1: ['colon cancer', 'colorectal cancer', 'colorectal cancers'] (DiseaseOrPhenotypicFeature), Entity2: ['AKT'] (GeneOrGeneProduct)
# 14. Entity1: ['colon cancer', 'colorectal cancer', 'colorectal cancers'] (DiseaseOrPhenotypicFeature), Entity2: ['BRAF'] (GeneOrGeneProduct)
# 15. Entity1: ['colon cancer', 'colorectal cancer', 'colorectal cancers'] (DiseaseOrPhenotypicFeature), Entity2: ['p53'] (GeneOrGeneProduct)
# 16. Entity1: ['Vitamin D'] (ChemicalEntity), Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'] (GeneOrGeneProduct)
# 17. Entity1: ['Vitamin D'] (ChemicalEntity), Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'] (DiseaseOrPhenotypicFeature)
# 18. Entity1: ['Vitamin D'] (ChemicalEntity), Entity2: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature)
# 19. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'] (GeneOrGeneProduct)
# 20. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'] (GeneOrGeneProduct)
# 21. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['KRAS', 'RAS'] (GeneOrGeneProduct)
# 22. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['MAPK', 'mitogen-activated protein kinase'] (GeneOrGeneProduct)
# 23. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['AKT'] (GeneOrGeneProduct)
# 24. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['BRAF'] (GeneOrGeneProduct)
# 25. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['p21'] (GeneOrGeneProduct)
# 26. Entity1: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature), Entity2: ['cyclooxygenase-2'] (GeneOrGeneProduct)
# 27. Entity1: ['MAPK', 'mitogen-activated protein kinase'] (GeneOrGeneProduct), Entity2: ['MAPK', 'mitogen-activated protein kinase'] (GeneOrGeneProduct)
# 28. Entity1: ['MAPK', 'mitogen-activated protein kinase'] (GeneOrGeneProduct), Entity2: ['AKT'] (GeneOrGeneProduct)
# 29. Entity1: ['CACNA1G'] (GeneOrGeneProduct), Entity2: ['cancers', 'tumor', 'tumors'] (DiseaseOrPhenotypicFeature)
# 30. Entity1: ['CACNA1G'] (GeneOrGeneProduct), Entity2: ['SOCS1'] (GeneOrGeneProduct)
# 31. Entity1: ['CDKN2A', 'p16'] (GeneOrGeneProduct), Entity2: ['MLH1'] (GeneOrGeneProduct)
# 32. Entity1: ['CRABP1'] (GeneOrGeneProduct), Entity2: ['p21'] (GeneOrGeneProduct)
# 33. Entity1: ['IGF2'] (GeneOrGeneProduct), Entity2: ['RUNX3'] (GeneOrGeneProduct)
# 34. Entity1: ['NEUROG1'] (GeneOrGeneProduct), Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'] (GeneOrGeneProduct)
# 35. Entity1: ['SOCS1'] (GeneOrGeneProduct), Entity2: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'] (GeneOrGeneProduct)
# 36. Entity1: ['SOCS1'] (GeneOrGeneProduct), Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'] (DiseaseOrPhenotypicFeature)
# 37. Entity1: ['BRAF'] (GeneOrGeneProduct), Entity2: ['KRAS', 'RAS'] (GeneOrGeneProduct)
# 38. Entity1: ['p53'] (GeneOrGeneProduct), Entity2: ['KRAS', 'RAS'] (GeneOrGeneProduct)
# 39. Entity1: ['beta-catenin'] (GeneOrGeneProduct), Entity2: ['AKT'] (GeneOrGeneProduct)
# ## Output:
# 1. Entity1: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Entity2: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Relation: No_Relation
# 2. Entity1: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Relation: Association
# 3. Entity1: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Entity2: ['KRAS', 'RAS'], Relation: Association
# 4. Entity1: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Relation: Positive_Correlation
# 5. Entity1: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Entity2: ['Vitamin D'], Relation: Bind
# 6. Entity1: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Relation: No_Relation
# 7. Entity1: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Entity2: ['KRAS', 'RAS'], Relation: No_Relation
# 8. Entity1: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Relation: Association
# 9. Entity1: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Entity2: ['AKT'], Relation: Association
# 10. Entity1: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Entity2: ['NEUROG1'], Relation: No_Relation
# 11. Entity1: ['KRAS', 'RAS'], Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Relation: Association
# 12. Entity1: ['KRAS', 'RAS'], Entity2: ['MAPK', 'mitogen-activated protein kinase'], Relation: Association
# 13. Entity1: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Entity2: ['AKT'], Relation: No_Relation
# 14. Entity1: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Entity2: ['BRAF'], Relation: No_Relation
# 15. Entity1: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Entity2: ['p53'], Relation: No_Relation
# 16. Entity1: ['Vitamin D'], Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Relation: No_Relation
# 17. Entity1: ['Vitamin D'], Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Relation: Negative_Correlation
# 18. Entity1: ['Vitamin D'], Entity2: ['cancers', 'tumor', 'tumors'], Relation: Negative_Correlation
# 19. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Relation: Positive_Correlation
# 20. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Relation: No_Relation
# 21. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['KRAS', 'RAS'], Relation: No_Relation
# 22. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['MAPK', 'mitogen-activated protein kinase'], Relation: No_Relation
# 23. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['AKT'], Relation: No_Relation
# 24. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['BRAF'], Relation: No_Relation
# 25. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['p21'], Relation: No_Relation
# 26. Entity1: ['cancers', 'tumor', 'tumors'], Entity2: ['cyclooxygenase-2'], Relation: No_Relation
# 27. Entity1: ['MAPK', 'mitogen-activated protein kinase'], Entity2: ['MAPK', 'mitogen-activated protein kinase'], Relation: No_Relation
# 28. Entity1: ['MAPK', 'mitogen-activated protein kinase'], Entity2: ['AKT'], Relation: No_Relation
# 29. Entity1: ['CACNA1G'], Entity2: ['cancers', 'tumor', 'tumors'], Relation: No_Relation
# 30. Entity1: ['CACNA1G'], Entity2: ['SOCS1'], Relation: No_Relation
# 31. Entity1: ['CDKN2A', 'p16'], Entity2: ['MLH1'], Relation: No_Relation
# 32. Entity1: ['CRABP1'], Entity2: ['p21'], Relation: No_Relation
# 33. Entity1: ['IGF2'], Entity2: ['RUNX3'], Relation: No_Relation
# 34. Entity1: ['NEUROG1'], Entity2: ['PI3K', 'PIK3CA', 'phosphatidylinositol 3-kinase'], Relation: No_Relation
# 35. Entity1: ['SOCS1'], Entity2: ['VDR', 'Vitamin D receptor', 'vitamin D receptor'], Relation: No_Relation
# 36. Entity1: ['SOCS1'], Entity2: ['colon cancer', 'colorectal cancer', 'colorectal cancers'], Relation: No_Relation
# 37. Entity1: ['BRAF'], Entity2: ['KRAS', 'RAS'], Relation: No_Relation
# 38. Entity1: ['p53'], Entity2: ['KRAS', 'RAS'], Relation: No_Relation
# 39. Entity1: ['beta-catenin'], Entity2: ['AKT'], Relation: No_Relation
#
# Example 8
# ## Input:
# Text: Effects of dehydroepiandrosterone in amphetamine-induced schizophrenia models in mice. OBJECTIVE: To examine the effects of dehydroepiandrosterone (DHEA) on animal models of schizophrenia. METHODS: Seventy Swiss albino female mice (25-35 g) were divided into 4 groups: amphetamine-free (control), amphetamine, 50, and 100 mg/kg DHEA. The DHEA was administered intraperitoneally (ip) for 5 days. Amphetamine (3 mg/kg ip) induced hyper locomotion, apomorphine (1.5 mg/kg subcutaneously [sc]) induced climbing, and haloperidol (1.5 mg/kg sc) induced catalepsy tests were used as animal models of schizophrenia. The study was conducted at the Animal Experiment Laboratories, Department of Pharmacology, Medical School, Eskisehir Osmangazi University, Eskisehir, Turkey between March and May 2012. Statistical analysis was carried out using Kruskal-Wallis test for hyper locomotion, and one-way ANOVA for climbing and catalepsy tests. RESULTS: In the amphetamine-induced locomotion test, there were significant increases in all movements compared with the amphetamine-free group. Both DHEA 50 mg/kg (p<0.05), and 100 mg/kg (p<0.01) significantly decreased all movements compared with the amphetamine-induced locomotion group. There was a significant difference between groups in the haloperidol-induced catalepsy test (p<0.05). There was no significant difference between groups in terms of total climbing time in the apomorphine-induced climbing test (p>0.05). CONCLUSION: We observed that DHEA reduced locomotor activity and increased catalepsy at both doses, while it had no effect on climbing behavior. We suggest that DHEA displays typical neuroleptic-like effects, and may be used in the treatment of schizophrenia.
# Entities:
# 1. Entity1: ['DHEA', 'dehydroepiandrosterone'] (ChemicalEntity), Entity2: ['Amphetamine', 'amphetamine'] (ChemicalEntity)
# 2. Entity1: ['DHEA', 'dehydroepiandrosterone'] (ChemicalEntity), Entity2: ['schizophrenia'] (DiseaseOrPhenotypicFeature)
# 3. Entity1: ['DHEA', 'dehydroepiandrosterone'] (ChemicalEntity), Entity2: ['hyper locomotion'] (DiseaseOrPhenotypicFeature)
# 4. Entity1: ['DHEA', 'dehydroepiandrosterone'] (ChemicalEntity), Entity2: ['catalepsy'] (DiseaseOrPhenotypicFeature)
# 5. Entity1: ['Amphetamine', 'amphetamine'] (ChemicalEntity), Entity2: ['schizophrenia'] (DiseaseOrPhenotypicFeature)
# 6. Entity1: ['Amphetamine', 'amphetamine'] (ChemicalEntity), Entity2: ['hyper locomotion'] (DiseaseOrPhenotypicFeature)
# 7. Entity1: ['Amphetamine', 'amphetamine'] (ChemicalEntity), Entity2: ['haloperidol'] (ChemicalEntity)
# 8. Entity1: ['hyper locomotion'] (DiseaseOrPhenotypicFeature), Entity2: ['apomorphine'] (ChemicalEntity)
# 9. Entity1: ['apomorphine'] (ChemicalEntity), Entity2: ['schizophrenia'] (DiseaseOrPhenotypicFeature)
# 10. Entity1: ['haloperidol'] (ChemicalEntity), Entity2: ['schizophrenia'] (DiseaseOrPhenotypicFeature)
# 11. Entity1: ['haloperidol'] (ChemicalEntity), Entity2: ['catalepsy'] (DiseaseOrPhenotypicFeature)
# 12. Entity1: ['catalepsy'] (DiseaseOrPhenotypicFeature), Entity2: ['Amphetamine', 'amphetamine'] (ChemicalEntity)
# ## Output:
# 1. Entity1: ['DHEA', 'dehydroepiandrosterone'], Entity2: ['Amphetamine', 'amphetamine'], Relation: Comparison
# 2. Entity1: ['DHEA', 'dehydroepiandrosterone'], Entity2: ['schizophrenia'], Relation: Negative_Correlation
# 3. Entity1: ['DHEA', 'dehydroepiandrosterone'], Entity2: ['hyper locomotion'], Relation: No_Relation
# 4. Entity1: ['DHEA', 'dehydroepiandrosterone'], Entity2: ['catalepsy'], Relation: Positive_Correlation
# 5. Entity1: ['Amphetamine', 'amphetamine'], Entity2: ['schizophrenia'], Relation: Positive_Correlation
# 6. Entity1: ['Amphetamine', 'amphetamine'], Entity2: ['hyper locomotion'], Relation: Positive_Correlation
# 7. Entity1: ['Amphetamine', 'amphetamine'], Entity2: ['haloperidol'], Relation: No_Relation
# 8. Entity1: ['hyper locomotion'], Entity2: ['apomorphine'], Relation: No_Relation
# 9. Entity1: ['apomorphine'], Entity2: ['schizophrenia'], Relation: No_Relation
# 10. Entity1: ['haloperidol'], Entity2: ['schizophrenia'], Relation: No_Relation
# 11. Entity1: ['haloperidol'], Entity2: ['catalepsy'], Relation: Positive_Correlation
# 12. Entity1: ['catalepsy'], Entity2: ['Amphetamine', 'amphetamine'], Relation: No_Relation
#
# ---
#
# Analyze this case:
# Text: Hepatocyte nuclear factor-6: associations between genetic variability and type II diabetes and between genetic variability and estimates of insulin secretion. The transcription factor hepatocyte nuclear factor (HNF)-6 is an upstream regulator of several genes involved in the pathogenesis of maturity-onset diabetes of the young. We therefore tested the hypothesis that variability in the HNF-6 gene is associated with subsets of Type II (non-insulin-dependent) diabetes mellitus and estimates of insulin secretion in glucose tolerant subjects.   We cloned the coding region as well as the intron-exon boundaries of the HNF-6 gene. We then examined them on genomic DNA in six MODY probands without mutations in the MODY1, MODY3 and MODY4 genes and in 54 patients with late-onset Type II diabetes by combined single strand conformational polymorphism-heteroduplex analysis followed by direct sequencing of identified variants. An identified missense variant was examined in association studies and genotype-phenotype studies.   We identified two silent and one missense (Pro75 Ala) variant. In an association study the allelic frequency of the Pro75Ala polymorphism was 3.2% (95% confidence interval, 1.9-4.5) in 330 patients with Type II diabetes mellitus compared with 4.2% (2.4-6.0) in 238 age-matched glucose tolerant control subjects. Moreover, in studies of 238 middle-aged glucose tolerant subjects, of 226 glucose tolerant offspring of Type II diabetic patients and of 367 young healthy subjects, the carriers of the polymorphism did not differ from non-carriers in glucose induced serum insulin or C-peptide responses.   Mutations in the coding region of the HNF-6 gene are not associated with Type II diabetes or with changes in insulin responses to glucose among the Caucasians examined.
# Entities:
# 1. Entity1: ['HNF-6', 'Hepatocyte nuclear factor-6', 'hepatocyte nuclear factor (HNF)-6'] (GeneOrGeneProduct), Entity2: ['Type II (non-insulin-dependent) diabetes mellitus', 'Type II diabetes', 'Type II diabetes mellitus', 'Type II diabetic', 'maturity-onset diabetes', 'type II diabetes'] (DiseaseOrPhenotypicFeature)
# 2. Entity1: ['Type II (non-insulin-dependent) diabetes mellitus', 'Type II diabetes', 'Type II diabetes mellitus', 'Type II diabetic', 'maturity-onset diabetes', 'type II diabetes'] (DiseaseOrPhenotypicFeature), Entity2: ['C-peptide', 'insulin'] (GeneOrGeneProduct)
# 3. Entity1: ['glucose'] (ChemicalEntity), Entity2: ['HNF-6', 'Hepatocyte nuclear factor-6', 'hepatocyte nuclear factor (HNF)-6'] (GeneOrGeneProduct)
# 4. Entity1: ['glucose'] (ChemicalEntity), Entity2: ['Type II (non-insulin-dependent) diabetes mellitus', 'Type II diabetes', 'Type II diabetes mellitus', 'Type II diabetic', 'maturity-onset diabetes', 'type II diabetes'] (DiseaseOrPhenotypicFeature)
# 5. Entity1: ['glucose'] (ChemicalEntity), Entity2: ['C-peptide', 'insulin'] (GeneOrGeneProduct)
# 6. Entity1: ['glucose'] (ChemicalEntity), Entity2: ['MODY', 'MODY4'] (GeneOrGeneProduct)
# 7. Entity1: ['MODY', 'MODY1'] (GeneOrGeneProduct), Entity2: ['Type II (non-insulin-dependent) diabetes mellitus', 'Type II diabetes', 'Type II diabetes mellitus', 'Type II diabetic', 'maturity-onset diabetes', 'type II diabetes'] (DiseaseOrPhenotypicFeature)
# 8. Entity1: ['MODY', 'MODY4'] (GeneOrGeneProduct), Entity2: ['Type II (non-insulin-dependent) diabetes mellitus', 'Type II diabetes', 'Type II diabetes mellitus', 'Type II diabetic', 'maturity-onset diabetes', 'type II diabetes'] (DiseaseOrPhenotypicFeature)
# 9. Entity1: ['MODY', 'MODY1'] (GeneOrGeneProduct), Entity2: ['glucose'] (ChemicalEntity)
# 10. Entity1: ['MODY', 'MODY1'] (GeneOrGeneProduct), Entity2: ['MODY', 'MODY3'] (GeneOrGeneProduct)
# 11. Entity1: ['Pro75 Ala', 'Pro75Ala'] (SequenceVariant), Entity2: ['Type II (non-insulin-dependent) diabetes mellitus', 'Type II diabetes', 'Type II diabetes mellitus', 'Type II diabetic', 'maturity-onset diabetes', 'type II diabetes'] (DiseaseOrPhenotypicFeature)
# 12. Entity1: ['Pro75 Ala', 'Pro75Ala'] (SequenceVariant), Entity2: ['glucose'] (ChemicalEntity)
#
# Respond in the following format:
# Reasoning: [one sentence explaining why]
# Relation: [a numbered list of all entetiy pairs and their relations]

# %%
import numpy as np

def consolidate_prompt_jsons(json_paths, prompt_set_names, output_path):
    """
    Merge multiple prompt JSONs into one, each as a different prompt set name.
    Also adds Multi_Relations and Multi_DocID fields if present and not already in the base.
    """
    import json

    # Load all JSONs
    jsons = [json.load(open(p, "r", encoding="utf-8")) for p in json_paths]
    base = jsons[0]
    n_key = list(base.keys())[0]
    runs = base[n_key].keys()

    # For each run, add all prompt sets and Multi fields if present
    for run in runs:
        for i, js in enumerate(jsons):
            prompt_set_name = prompt_set_names[i]
            # Find the first prompt set key in this json (e.g. "prompts1")
            prompt_set_key = [k for k in js[n_key][run].keys() if k.startswith("prompts")][0]
            base[n_key][run][prompt_set_name] = js[n_key][run][prompt_set_key]
            # Add Multi_Relations if present and not already in base
            if "multi_relations" in js[n_key][run] and "multi_relations" not in base[n_key][run]:
                base[n_key][run]["multi_relations"] = js[n_key][run]["multi_relations"]
            # Add Multi_DocID if present and not already in base
            if "multi_docid" in js[n_key][run] and "multi_docid" not in base[n_key][run]:
                base[n_key][run]["multi_docid"] = js[n_key][run]["multi_docid"]

    # Save merged JSON
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(base, f, indent=2)

# Set your seed for reproducibility
seed = 42
np.random.seed(seed)

# Get unique doc_ids
unique_docids = merged_df_train['doc_id'].unique()

# Pick 20 random doc_ids
sampled_docids = np.random.choice(unique_docids, size=20, replace=False)

# Subset the DataFrame to only rows with those doc_ids
subset_df = merged_df_train[merged_df_train['doc_id'].isin(sampled_docids)].copy()

print(subset_df.shape)
print(subset_df['doc_id'].unique())

template_path_multi = "LLM_benchmarks/prompt_template_multi.txt"
template_path_single = "LLM_benchmarks/prompt_template_single.txt"
template_path_single_wo_reason = "LLM_benchmarks/prompt_template_single_wo_reason.txt"

test_single = create_prompt_relation_df_single(subset_df,merged_df_test, template_path_single, examples=False,same_examples=False, seed=42, n_prompts=5, prompt_id=False)
print(test_single.head())
import json
prompt_json = prompts_df_to_json_from_runs(test_single)
with open("LLM_benchmarks/Prompts/test_single_for_api.json", "w") as f:
    json.dump(prompt_json, f, indent=2)

test_single_w_examples = create_prompt_relation_df_single(subset_df,merged_df_test, template_path_single, examples=True,same_examples=True, seed=42, n_prompts=5, prompt_id=False)
print(test_single_w_examples.head())
import json
prompt_json = prompts_df_to_json_from_runs(test_single_w_examples)
with open("LLM_benchmarks/Prompts/test_single_for_api_examples.json", "w") as f:
    json.dump(prompt_json, f, indent=2)

test_multi = create_prompt_relation_df_multi_by_docid(subset_df,merged_df_test, template_path_multi, examples=False,same_examples=False, seed=42, n_prompts=5, number_relations=True, relations_entitys_separately=False)
print(test_multi.head())
import json
prompt_json = prompts_df_to_json_from_runs_multi(test_multi)
with open("LLM_benchmarks/Prompts/test_multi_for_api.json", "w") as f:
    json.dump(prompt_json, f, indent=2) 

test_multi_w_examples = create_prompt_relation_df_multi_by_docid(subset_df,merged_df_test, template_path_multi, examples=True,same_examples=True, seed=42, n_prompts=5, number_relations=True, relations_entitys_separately=False)
print(test_multi_w_examples.head())
import json
prompt_json = prompts_df_to_json_from_runs_multi(test_multi_w_examples)
with open("LLM_benchmarks/Prompts/test_multi_for_api_examples.json", "w") as f:
    json.dump(prompt_json, f, indent=2)

consolidate_prompt_jsons(
    [
        "LLM_benchmarks/Prompts/test_single_for_api.json",
        "LLM_benchmarks/Prompts/test_single_for_api_examples.json",
        "LLM_benchmarks/Prompts/test_multi_for_api.json",
        "LLM_benchmarks/Prompts/test_multi_for_api_examples.json"
    ],
    ["single_zero", "single_examples", "multi_zero", "multi_examples"],
    "LLM_benchmarks/Prompts/Test_callibration.json"
)
calibration_test = json.load(open("LLM_benchmarks/Prompts/Test_callibration.json", "r", encoding="utf-8"))
# Out:
# (384, 20)
# ['15033202' '15623763' '15814629' '16158428' '16541406' '16755009'
#  '17000021' '17003357' '17634480' '17951029' '19463742' '19696792'
#  '19996135' '20105280' '21615796' '27930654' '28260056' '28428256'
#  '28487437' '28650467']
#                                               Prompt              Relation  \
# 0  You are a biomedical relation extraction exper...  Positive_Correlation
# 1  You are a biomedical relation extraction exper...           Association
# 2  You are a biomedical relation extraction exper...           No_Relation
# 3  You are a biomedical relation extraction exper...           No_Relation
# 4  You are a biomedical relation extraction exper...           No_Relation
#
#       DocID  run  prompt_id
# 0  15033202    1          1
# 1  15033202    1          2
# 2  15033202    1          3
# 3  15033202    1          4
# 4  15033202    1          5
#                                               Prompt              Relation  \
# 0  You are a biomedical relation extraction exper...  Positive_Correlation
# 1  You are a biomedical relation extraction exper...           Association
# 2  You are a biomedical relation extraction exper...           No_Relation
# 3  You are a biomedical relation extraction exper...           No_Relation
# 4  You are a biomedical relation extraction exper...           No_Relation
#
#       DocID  run  prompt_id
# 0  15033202    1          1
# 1  15033202    1          2
# 2  15033202    1          3
# 3  15033202    1          4
# 4  15033202    1          5
#                                               Prompt  \
# 0  You are a biomedical relation extraction exper...
# 1  You are a biomedical relation extraction exper...
# 2  You are a biomedical relation extraction exper...
# 3  You are a biomedical relation extraction exper...
# 4  You are a biomedical relation extraction exper...
#
#                                      Multi_Relations Multi_DocID  run
# 0  [Positive_Correlation, Association, No_Relatio...    15033202    1
# 1  [Association, Association, Association, No_Rel...    15623763    1
# 2  [Association, No_Relation, Association, No_Rel...    15814629    1
# 3            [Association, Association, Association]    16158428    1
# 4            [No_Relation, Association, Association]    16541406    1
#                                               Prompt  \
# 0  You are a biomedical relation extraction exper...
# 1  You are a biomedical relation extraction exper...
# 2  You are a biomedical relation extraction exper...
# 3  You are a biomedical relation extraction exper...
# 4  You are a biomedical relation extraction exper...
#
#                                      Multi_Relations Multi_DocID  run
# 0  [Positive_Correlation, Association, No_Relatio...    15033202    1
# 1  [Association, Association, Association, No_Rel...    15623763    1
# 2  [Association, No_Relation, Association, No_Rel...    15814629    1
# 3            [Association, Association, Association]    16158428    1
# 4            [No_Relation, Association, Association]    16541406    1

# %%
print(calibration_test["n_1"]["run_1"]["multi_examples"][0])
print(calibration_test["n_1"]["run_1"]["single_examples"][0])
# Out:
# You are a biomedical relation extraction expert following BioRED annotation guidelines.
#
# Task: Identify the relation type between two specified entities.
#
# Valid relation types (respond with EXACTLY ONE of these words):
# - Relation: A meaningful connection or interaction between two entities, which may include associations, correlations (positive or negative), physical binding, comparisons, conversions, co-treatments, or drug interactions.
# - No_Relation: Two enteties that are not directly related according to the text.
#
# CRITICAL INSTRUCTIONS:
# 1. Only annotate EXPLICIT relations stated in the text
# 2. If entities co-occur WITHOUT a clear relationship → respond with "No_Relation"
# 3. Do NOT infer or assume relationships not explicitly stated
# 4. When uncertain → respond with "No_Relation"
# Example 1
# ## Input:
# Text: Effect of alpha-tocopherol and deferoxamine on methamphetamine-induced neurotoxicity. Methamphetamine (MA)-induced dopaminergic neurotoxicity is believed to be associated with the increased formation of free radicals. This study examined the effect of alpha-tocopherol (alpha-TC), a scavenger of reactive oxygen species, and deferoxamine (DFO), an iron chelator, on the MA-induced neurotoxicity. Male rats were treated with MA (10 mg/kg, every 2 h for four injections). The rat received either alpha-TC (20 mg/kg) intraperitoneally for 3 days and 30 min prior to MA administration or DFO (50 mg/kg) subcutaneously 30 min before MA administration. The concentrations of dopamine (DA), serotonin and their metabolites decreased significantly after MA administration, which was inhibited by the alpha-TC and DFO pretreatment. alpha-TC and DFO attenuated the MA-induced hyperthermia as well as the alterations in the locomotor activity. The level of lipid peroxidation was higher and the reduced glutathione concentration was lower in the MA-treated rats. These changes were significantly attenuated by alpha-TC and DFO. This suggests that alpha-TC and DFO ameliorate the MA-induced neuronal damage by decreasing the level of oxidative stress.
# Entities:
# 1. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity)
# 2. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 3. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['DA', 'dopamine', 'dopaminergic'] (ChemicalEntity)
# 4. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['reactive oxygen species'] (ChemicalEntity)
# 5. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['serotonin'] (ChemicalEntity)
# 6. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['hyperthermia'] (DiseaseOrPhenotypicFeature)
# 7. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['lipid'] (ChemicalEntity)
# 8. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['glutathione'] (ChemicalEntity)
# 9. Entity1: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity), Entity2: ['neuronal damage'] (DiseaseOrPhenotypicFeature)
# 10. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['alpha-TC', 'alpha-tocopherol'] (ChemicalEntity)
# 11. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 12. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['DA', 'dopamine', 'dopaminergic'] (ChemicalEntity)
# 13. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['iron'] (ChemicalEntity)
# 14. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['serotonin'] (ChemicalEntity)
# 15. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['hyperthermia'] (DiseaseOrPhenotypicFeature)
# 16. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['lipid'] (ChemicalEntity)
# 17. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['glutathione'] (ChemicalEntity)
# 18. Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['neuronal damage'] (DiseaseOrPhenotypicFeature)
# 19. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 20. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity), Entity2: ['neurotoxicity'] (DiseaseOrPhenotypicFeature)
# 21. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity), Entity2: ['hyperthermia'] (DiseaseOrPhenotypicFeature)
# 22. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity), Entity2: ['neuronal damage'] (DiseaseOrPhenotypicFeature)
# 23. Entity1: ['neurotoxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['DFO', 'deferoxamine'] (ChemicalEntity)
# 24. Entity1: ['DA', 'dopamine', 'dopaminergic'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 25. Entity1: ['DA', 'dopamine', 'dopaminergic'] (ChemicalEntity), Entity2: ['neurotoxicity'] (DiseaseOrPhenotypicFeature)
# 26. Entity1: ['reactive oxygen species'] (ChemicalEntity), Entity2: ['neurotoxicity'] (DiseaseOrPhenotypicFeature)
# 27. Entity1: ['serotonin'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 28. Entity1: ['serotonin'] (ChemicalEntity), Entity2: ['hyperthermia'] (DiseaseOrPhenotypicFeature)
# 29. Entity1: ['hyperthermia'] (DiseaseOrPhenotypicFeature), Entity2: ['glutathione'] (ChemicalEntity)
# 30. Entity1: ['lipid'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 31. Entity1: ['glutathione'] (ChemicalEntity), Entity2: ['MA', 'Methamphetamine', 'methamphetamine'] (ChemicalEntity)
# 32. Entity1: ['glutathione'] (ChemicalEntity), Entity2: ['neuronal damage'] (DiseaseOrPhenotypicFeature)
# ## Output:
# 1. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['alpha-TC', 'alpha-tocopherol'], Relation: No_Relation
# 2. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: Relation
# 3. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['DA', 'dopamine', 'dopaminergic'], Relation: Relation
# 4. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['reactive oxygen species'], Relation: Relation
# 5. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['serotonin'], Relation: Relation
# 6. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['hyperthermia'], Relation: Relation
# 7. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['lipid'], Relation: Relation
# 8. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['glutathione'], Relation: Relation
# 9. Entity1: ['alpha-TC', 'alpha-tocopherol'], Entity2: ['neuronal damage'], Relation: Relation
# 10. Entity1: ['DFO', 'deferoxamine'], Entity2: ['alpha-TC', 'alpha-tocopherol'], Relation: No_Relation
# 11. Entity1: ['DFO', 'deferoxamine'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: Relation
# 12. Entity1: ['DFO', 'deferoxamine'], Entity2: ['DA', 'dopamine', 'dopaminergic'], Relation: Relation
# 13. Entity1: ['DFO', 'deferoxamine'], Entity2: ['iron'], Relation: Relation
# 14. Entity1: ['DFO', 'deferoxamine'], Entity2: ['serotonin'], Relation: Relation
# 15. Entity1: ['DFO', 'deferoxamine'], Entity2: ['hyperthermia'], Relation: Relation
# 16. Entity1: ['DFO', 'deferoxamine'], Entity2: ['lipid'], Relation: Relation
# 17. Entity1: ['DFO', 'deferoxamine'], Entity2: ['glutathione'], Relation: Relation
# 18. Entity1: ['DFO', 'deferoxamine'], Entity2: ['neuronal damage'], Relation: Relation
# 19. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: No_Relation
# 20. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'], Entity2: ['neurotoxicity'], Relation: Relation
# 21. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'], Entity2: ['hyperthermia'], Relation: Relation
# 22. Entity1: ['MA', 'Methamphetamine', 'methamphetamine'], Entity2: ['neuronal damage'], Relation: Relation
# 23. Entity1: ['neurotoxicity'], Entity2: ['DFO', 'deferoxamine'], Relation: No_Relation
# 24. Entity1: ['DA', 'dopamine', 'dopaminergic'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: Relation
# 25. Entity1: ['DA', 'dopamine', 'dopaminergic'], Entity2: ['neurotoxicity'], Relation: Relation
# 26. Entity1: ['reactive oxygen species'], Entity2: ['neurotoxicity'], Relation: No_Relation
# 27. Entity1: ['serotonin'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: Relation
# 28. Entity1: ['serotonin'], Entity2: ['hyperthermia'], Relation: No_Relation
# 29. Entity1: ['hyperthermia'], Entity2: ['glutathione'], Relation: No_Relation
# 30. Entity1: ['lipid'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: Relation
# 31. Entity1: ['glutathione'], Entity2: ['MA', 'Methamphetamine', 'methamphetamine'], Relation: Relation
# 32. Entity1: ['glutathione'], Entity2: ['neuronal damage'], Relation: No_Relation
#
# Example 2
# ## Input:
# Text: Organophosphate-induced convulsions and prevention of neuropathological damages. Such organophosphorus (OP) compounds as diisopropylfluorophosphate (DFP), sarin and soman are potent inhibitors of acetylcholinesterases (AChEs) and butyrylcholinesterases (BChEs). The acute toxicity of OPs is the result of their irreversible binding with AChEs in the central nervous system (CNS), which elevates acetylcholine (ACh) levels. The protective action of subcutaneously (SC) administered antidotes or their combinations in DFP (2.0 mg/kg BW) intoxication was studied in 9-10-weeks-old Han-Wistar male rats. The rats received AChE reactivator pralidoxime-2-chloride (2PAM) (30.0 mg/kg BW), anticonvulsant diazepam (2.0 mg/kg BW), A(1)-adenosine receptor agonist N(6)-cyclopentyl adenosine (CPA) (2.0 mg/kg BW), NMDA-receptor antagonist dizocilpine maleate (+-MK801 hydrogen maleate) (2.0 mg/kg BW) or their combinations with cholinolytic drug atropine sulfate (50.0 mg/kg BW) immediately or 30 min after the single SC injection of DFP. The control rats received atropine sulfate, but also saline and olive oil instead of other antidotes and DFP, respectively. All rats were terminated either 24 h or 3 weeks after the DFP injection. The rats treated with DFP-atropine showed severe typical OP-induced toxicity signs. When CPA, diazepam or 2PAM was given immediately after DFP-atropine, these treatments prevented, delayed or shortened the occurrence of serious signs of poisoning. Atropine-MK801 did not offer any additional protection against DFP toxicity. In conclusion, CPA, diazepam and 2PAM in combination with atropine prevented the occurrence of serious signs of poisoning and thus reduced the toxicity of DFP in rat.
# Entities:
# 1. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['convulsions'] (DiseaseOrPhenotypicFeature)
# 2. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['neuropathological damages'] (DiseaseOrPhenotypicFeature)
# 3. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 4. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 5. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 6. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['ACh', 'acetylcholine'] (ChemicalEntity)
# 7. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 8. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity), Entity2: ['NMDA-receptor'] (GeneOrGeneProduct)
# 9. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 10. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 11. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 12. Entity1: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 13. Entity1: ['sarin'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 14. Entity1: ['sarin'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 15. Entity1: ['soman'] (ChemicalEntity), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 16. Entity1: ['soman'] (ChemicalEntity), Entity2: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct)
# 17. Entity1: ['soman'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 18. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 19. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['ACh', 'acetylcholine'] (ChemicalEntity)
# 20. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity)
# 21. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['diazepam'] (ChemicalEntity)
# 22. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 23. Entity1: ['BChEs', 'butyrylcholinesterases'] (GeneOrGeneProduct), Entity2: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity)
# 24. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 25. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# 26. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity)
# 27. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 28. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 29. Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['olive oil'] (ChemicalEntity)
# 30. Entity1: ['ACh', 'acetylcholine'] (ChemicalEntity), Entity2: ['diazepam'] (ChemicalEntity)
# 31. Entity1: ['ACh', 'acetylcholine'] (ChemicalEntity), Entity2: ['NMDA-receptor'] (GeneOrGeneProduct)
# 32. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 33. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['diazepam'] (ChemicalEntity)
# 34. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 35. Entity1: ['2PAM', 'pralidoxime-2-chloride'] (ChemicalEntity), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 36. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 37. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 38. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 39. Entity1: ['diazepam'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 40. Entity1: ['A(1)-adenosine receptor'] (GeneOrGeneProduct), Entity2: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'] (ChemicalEntity)
# 41. Entity1: ['A(1)-adenosine receptor'] (GeneOrGeneProduct), Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity)
# 42. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 43. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['diazepam'] (ChemicalEntity)
# 44. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# 45. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 46. Entity1: ['NMDA-receptor'] (GeneOrGeneProduct), Entity2: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity)
# 47. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 48. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 49. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'] (ChemicalEntity), Entity2: ['olive oil'] (ChemicalEntity)
# 50. Entity1: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 51. Entity1: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity), Entity2: ['toxicity'] (DiseaseOrPhenotypicFeature)
# 52. Entity1: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity), Entity2: ['poisoning'] (DiseaseOrPhenotypicFeature)
# 53. Entity1: ['poisoning'] (DiseaseOrPhenotypicFeature), Entity2: ['DFP', 'diisopropylfluorophosphate'] (ChemicalEntity)
# 54. Entity1: ['poisoning'] (DiseaseOrPhenotypicFeature), Entity2: ['Atropine', 'atropine', 'atropine sulfate'] (ChemicalEntity)
# ## Output:
# 1. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['convulsions'], Relation: Relation
# 2. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['neuropathological damages'], Relation: Relation
# 3. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Relation
# 4. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Relation
# 5. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['toxicity'], Relation: No_Relation
# 6. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['ACh', 'acetylcholine'], Relation: Relation
# 7. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: No_Relation
# 8. Entity1: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Entity2: ['NMDA-receptor'], Relation: No_Relation
# 9. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 10. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Relation
# 11. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Relation
# 12. Entity1: ['DFP', 'diisopropylfluorophosphate'], Entity2: ['poisoning'], Relation: No_Relation
# 13. Entity1: ['sarin'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Relation
# 14. Entity1: ['sarin'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Relation
# 15. Entity1: ['soman'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: Relation
# 16. Entity1: ['soman'], Entity2: ['BChEs', 'butyrylcholinesterases'], Relation: Relation
# 17. Entity1: ['soman'], Entity2: ['toxicity'], Relation: No_Relation
# 18. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: No_Relation
# 19. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['ACh', 'acetylcholine'], Relation: Relation
# 20. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['2PAM', 'pralidoxime-2-chloride'], Relation: Relation
# 21. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['diazepam'], Relation: No_Relation
# 22. Entity1: ['AChE', 'AChEs', 'acetylcholinesterases'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: No_Relation
# 23. Entity1: ['BChEs', 'butyrylcholinesterases'], Entity2: ['2PAM', 'pralidoxime-2-chloride'], Relation: No_Relation
# 24. Entity1: ['toxicity'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 25. Entity1: ['toxicity'], Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'], Relation: No_Relation
# 26. Entity1: ['toxicity'], Entity2: ['2PAM', 'pralidoxime-2-chloride'], Relation: No_Relation
# 27. Entity1: ['toxicity'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: No_Relation
# 28. Entity1: ['toxicity'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: No_Relation
# 29. Entity1: ['toxicity'], Entity2: ['olive oil'], Relation: No_Relation
# 30. Entity1: ['ACh', 'acetylcholine'], Entity2: ['diazepam'], Relation: No_Relation
# 31. Entity1: ['ACh', 'acetylcholine'], Entity2: ['NMDA-receptor'], Relation: No_Relation
# 32. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Relation
# 33. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['diazepam'], Relation: Relation
# 34. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: Relation
# 35. Entity1: ['2PAM', 'pralidoxime-2-chloride'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: Relation
# 36. Entity1: ['diazepam'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Relation
# 37. Entity1: ['diazepam'], Entity2: ['toxicity'], Relation: No_Relation
# 38. Entity1: ['diazepam'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: Relation
# 39. Entity1: ['diazepam'], Entity2: ['poisoning'], Relation: No_Relation
# 40. Entity1: ['A(1)-adenosine receptor'], Entity2: ['OP', 'OPs', 'Organophosphate', 'organophosphorus'], Relation: No_Relation
# 41. Entity1: ['A(1)-adenosine receptor'], Entity2: ['CPA', 'N(6)-cyclopentyl adenosine'], Relation: Relation
# 42. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Relation
# 43. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['diazepam'], Relation: Relation
# 44. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: Relation
# 45. Entity1: ['CPA', 'N(6)-cyclopentyl adenosine'], Entity2: ['poisoning'], Relation: No_Relation
# 46. Entity1: ['NMDA-receptor'], Entity2: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Relation: Relation
# 47. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 48. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Entity2: ['toxicity'], Relation: No_Relation
# 49. Entity1: ['MK801', 'MK801 hydrogen maleate', 'dizocilpine maleate'], Entity2: ['olive oil'], Relation: No_Relation
# 50. Entity1: ['Atropine', 'atropine', 'atropine sulfate'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: Relation
# 51. Entity1: ['Atropine', 'atropine', 'atropine sulfate'], Entity2: ['toxicity'], Relation: No_Relation
# 52. Entity1: ['Atropine', 'atropine', 'atropine sulfate'], Entity2: ['poisoning'], Relation: No_Relation
# 53. Entity1: ['poisoning'], Entity2: ['DFP', 'diisopropylfluorophosphate'], Relation: No_Relation
# 54. Entity1: ['poisoning'], Entity2: ['Atropine', 'atropine', 'atropine sulfate'], Relation: No_Relation
#
# ---
#
# Analyze this case:
# Text: Nijmegen breakage syndrome in 13% of age-matched Czech children with primary microcephaly. The Nijmegen breakage syndrome is a rare autosomal recessive chromosomal instability disorder characterized by early growth retardation, congenital microcephaly, immunodeficiency, borderline mental development, and a high tendency to lymphoreticular malignancies. Most Nijmegen breakage syndrome patients are of Slavonic origin, and all of them known so far carry a founder homozygous 5 nucleotide deletion in the NBS1 gene. Microcephaly was present in 100% of Nijmegen breakage syndrome patients in a recent large international cooperative study. The frequency of Nijmegen breakage syndrome among children with primary microcephaly was not known. Early correct diagnosis of the syndrome is crucial for appropriate preventive care and therapy. We tested 67 Czech patients of different ages with simple microcephaly for the presence of the most common mutation in the NBS1 gene. Three new Nijmegen breakage syndrome cases were detected in this cohort, representing 4.5% of the cohort. All these newly diagnosed Nijmegen breakage syndrome patients were younger than 10 months at the time of diagnosis. They were all born within a 2.5-year period. Twenty-three of the 67 children in the cohort were born within this 2.5-year period, representing a 13% incidence of Nijmegen breakage syndrome. Frequency of Nijmegen breakage syndrome heterozygotes among infants in the Czech Republic is 1: 130-158 and the birth rate is 90,000 per year, therefore in the time span of 2.5 years, three new Nijmegen breakage syndrome homozygotes are expected to be born. Therefore we assume that by DNA testing of Czech primary microcephalic children it is possible to detect all Nijmegen breakage syndrome patients to be expected. The age at correct diagnosis was lowered from 7.1 years at the time before DNA testing, to well under 1 year of age. All new Nijmegen breakage syndrome patients could receive appropriate preventive care, which should significantly improve their life expectancy and prognosis.
# Entities:
# 1. Entity1: ['Nijmegen breakage syndrome', 'lymphoreticular malignancies'] (DiseaseOrPhenotypicFeature), Entity2: ['5 nucleotide deletion'] (SequenceVariant)
# 2. Entity1: ['Nijmegen breakage syndrome', 'lymphoreticular malignancies'] (DiseaseOrPhenotypicFeature), Entity2: ['NBS1'] (GeneOrGeneProduct)
# 3. Entity1: ['Microcephaly', 'congenital microcephaly', 'primary microcephaly'] (DiseaseOrPhenotypicFeature), Entity2: ['5 nucleotide deletion'] (SequenceVariant)
# 4. Entity1: ['autosomal recessive chromosomal instability disorder'] (DiseaseOrPhenotypicFeature), Entity2: ['5 nucleotide deletion'] (SequenceVariant)
# 5. Entity1: ['immunodeficiency'] (DiseaseOrPhenotypicFeature), Entity2: ['5 nucleotide deletion'] (SequenceVariant)
#
# Respond in the following format:
# Reasoning: [one sentence explaining why]
# Relation: [a numbered list of all entetiy pairs and their relations]
#
# You are a biomedical relation extraction expert following BioRED annotation guidelines.
# Prompt_ID:
# Task: Identify the relation type between two specified entities.
#
# Valid relation types (respond with EXACTLY ONE of these words):
# - Relation: A meaningful connection or interaction between two entities, which may include associations, correlations (positive or negative), physical binding, comparisons, conversions, co-treatments, or drug interactions.
# - No_Relation: Two enteties that are not directly related according to the text.
#
# CRITICAL INSTRUCTIONS:
# 1. Only annotate EXPLICIT relations stated in the text
# 2. If entities co-occur WITHOUT a clear relationship → respond with "No_Relation"
# 3. Do NOT infer or assume relationships not explicitly stated
# 4. When uncertain → respond with "No_Relation"
# Example 1
# ## Input:
# Text: Effect of alpha-tocopherol and deferoxamine on methamphetamine-induced neurotoxicity. Methamphetamine (MA)-induced dopaminergic neurotoxicity is believed to be associated with the increased formation of free radicals. This study examined the effect of alpha-tocopherol (alpha-TC), a scavenger of reactive oxygen species, and deferoxamine (DFO), an iron chelator, on the MA-induced neurotoxicity. Male rats were treated with MA (10 mg/kg, every 2 h for four injections). The rat received either alpha-TC (20 mg/kg) intraperitoneally for 3 days and 30 min prior to MA administration or DFO (50 mg/kg) subcutaneously 30 min before MA administration. The concentrations of dopamine (DA), serotonin and their metabolites decreased significantly after MA administration, which was inhibited by the alpha-TC and DFO pretreatment. alpha-TC and DFO attenuated the MA-induced hyperthermia as well as the alterations in the locomotor activity. The level of lipid peroxidation was higher and the reduced glutathione concentration was lower in the MA-treated rats. These changes were significantly attenuated by alpha-TC and DFO. This suggests that alpha-TC and DFO ameliorate the MA-induced neuronal damage by decreasing the level of oxidative stress.
# Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['lipid'] (ChemicalEntity)
# ## Output:
# Entity1: ['DFO', 'deferoxamine'] (ChemicalEntity), Entity2: ['lipid'] (ChemicalEntity), Relation: Relation
#
# Example 2
# ## Input:
# Text: Organophosphate-induced convulsions and prevention of neuropathological damages. Such organophosphorus (OP) compounds as diisopropylfluorophosphate (DFP), sarin and soman are potent inhibitors of acetylcholinesterases (AChEs) and butyrylcholinesterases (BChEs). The acute toxicity of OPs is the result of their irreversible binding with AChEs in the central nervous system (CNS), which elevates acetylcholine (ACh) levels. The protective action of subcutaneously (SC) administered antidotes or their combinations in DFP (2.0 mg/kg BW) intoxication was studied in 9-10-weeks-old Han-Wistar male rats. The rats received AChE reactivator pralidoxime-2-chloride (2PAM) (30.0 mg/kg BW), anticonvulsant diazepam (2.0 mg/kg BW), A(1)-adenosine receptor agonist N(6)-cyclopentyl adenosine (CPA) (2.0 mg/kg BW), NMDA-receptor antagonist dizocilpine maleate (+-MK801 hydrogen maleate) (2.0 mg/kg BW) or their combinations with cholinolytic drug atropine sulfate (50.0 mg/kg BW) immediately or 30 min after the single SC injection of DFP. The control rats received atropine sulfate, but also saline and olive oil instead of other antidotes and DFP, respectively. All rats were terminated either 24 h or 3 weeks after the DFP injection. The rats treated with DFP-atropine showed severe typical OP-induced toxicity signs. When CPA, diazepam or 2PAM was given immediately after DFP-atropine, these treatments prevented, delayed or shortened the occurrence of serious signs of poisoning. Atropine-MK801 did not offer any additional protection against DFP toxicity. In conclusion, CPA, diazepam and 2PAM in combination with atropine prevented the occurrence of serious signs of poisoning and thus reduced the toxicity of DFP in rat.
# Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct)
# ## Output:
# Entity1: ['toxicity'] (DiseaseOrPhenotypicFeature), Entity2: ['AChE', 'AChEs', 'acetylcholinesterases'] (GeneOrGeneProduct), Relation: No_Relation
#
# ---
#
# Analyze this case:
# Text: Nijmegen breakage syndrome in 13% of age-matched Czech children with primary microcephaly. The Nijmegen breakage syndrome is a rare autosomal recessive chromosomal instability disorder characterized by early growth retardation, congenital microcephaly, immunodeficiency, borderline mental development, and a high tendency to lymphoreticular malignancies. Most Nijmegen breakage syndrome patients are of Slavonic origin, and all of them known so far carry a founder homozygous 5 nucleotide deletion in the NBS1 gene. Microcephaly was present in 100% of Nijmegen breakage syndrome patients in a recent large international cooperative study. The frequency of Nijmegen breakage syndrome among children with primary microcephaly was not known. Early correct diagnosis of the syndrome is crucial for appropriate preventive care and therapy. We tested 67 Czech patients of different ages with simple microcephaly for the presence of the most common mutation in the NBS1 gene. Three new Nijmegen breakage syndrome cases were detected in this cohort, representing 4.5% of the cohort. All these newly diagnosed Nijmegen breakage syndrome patients were younger than 10 months at the time of diagnosis. They were all born within a 2.5-year period. Twenty-three of the 67 children in the cohort were born within this 2.5-year period, representing a 13% incidence of Nijmegen breakage syndrome. Frequency of Nijmegen breakage syndrome heterozygotes among infants in the Czech Republic is 1: 130-158 and the birth rate is 90,000 per year, therefore in the time span of 2.5 years, three new Nijmegen breakage syndrome homozygotes are expected to be born. Therefore we assume that by DNA testing of Czech primary microcephalic children it is possible to detect all Nijmegen breakage syndrome patients to be expected. The age at correct diagnosis was lowered from 7.1 years at the time before DNA testing, to well under 1 year of age. All new Nijmegen breakage syndrome patients could receive appropriate preventive care, which should significantly improve their life expectancy and prognosis.
# Entity1: ['Nijmegen breakage syndrome', 'lymphoreticular malignancies'] (DiseaseOrPhenotypicFeature), Entity2: ['5 nucleotide deletion'] (SequenceVariant)
#
# Respond in the following format:
# Reasoning: [Explanaiton why]
# Relation: [one word from the list above]

# %%
import json
import pandas as pd
import random

def get_relations_from_json(json_data, run_key="run_1"):
    """Extract all relation types from a JSON dataset for a specific run."""
    relations = []
    
    # Check if multi_relations exists (for multi prompts)
    if "multi_relations" in json_data["n_1"][run_key]:
        for relation_list in json_data["n_1"][run_key]["multi_relations"]:
            relations.extend(relation_list)
    
    # Check if relations exists (for single prompts)
    if "relations" in json_data["n_1"][run_key]:
        relations.extend(json_data["n_1"][run_key]["relations"])
    
    return set(relations)


def find_missing_classes(json_path, all_classes):
    """Identify which relation classes are missing from the test dataset."""
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    # Check first run to see what's present
    present_classes = get_relations_from_json(data, "run_1")
    missing_classes = set(all_classes) - present_classes
    
    return list(missing_classes)


def find_abstracts_with_classes(df, missing_classes, seed=42):
    """Find one abstract (doc_id) for each missing class from the training data."""
    random.seed(seed)
    abstracts_to_add = {}
    
    for rel_class in missing_classes:
        # Find all doc_ids that contain this relation type
        matching_rows = df[df['relation_type'] == rel_class]
        
        if matching_rows.empty:
            print(f"Warning: No examples found for class '{rel_class}' in training data")
            continue
        
        # Get unique doc_ids
        doc_ids = matching_rows['doc_id'].unique()
        
        # Randomly select one doc_id
        selected_doc_id = random.choice(doc_ids)
        abstracts_to_add[rel_class] = selected_doc_id
    
    return abstracts_to_add


def append_missing_classes_to_json(
    json_path,
    train_df,
    test_df,
    template_path_single,
    template_path_multi,
    missing_classes,
    seed=42
):
    """
    Append prompts for missing classes to existing JSON file.
    
    Args:
        json_path: Path to the consolidated JSON file
        train_df: Training dataframe
        test_df: Test dataframe (for examples)
        template_path_single: Path to single prompt template
        template_path_multi: Path to multi prompt template
        missing_classes: List of missing relation classes
        seed: Random seed for reproducibility
    """
    # Load existing JSON
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    # Find abstracts containing missing classes
    abstracts_to_add = find_abstracts_with_classes(train_df, missing_classes, seed)
    
    if not abstracts_to_add:
        print("No abstracts to add - all missing classes not found in training data")
        return
    
    print(f"Adding {len(abstracts_to_add)} abstracts for missing classes: {list(abstracts_to_add.keys())}")
    
    # Import necessary functions from your notebook
    #from create_prompt_relation_df_single import create_prompt_relation_df_single
    #from create_prompt_relation_df_multi_by_docid import create_prompt_relation_df_multi_by_docid
    #from prompts_df_to_json_from_runs import prompts_df_to_json_from_runs
    #from prompts_df_to_json_from_runs_multi import prompts_df_to_json_from_runs_multi
    
    # For each run in the JSON
    for run_key in data["n_1"].keys():
        run_num = int(run_key.split("_")[1])
        
        for rel_class, doc_id in abstracts_to_add.items():
            # Get all rows for this doc_id
            doc_rows = train_df[train_df['doc_id'] == doc_id].copy()
            
            print(f"  Adding abstract {doc_id} (class: {rel_class}) to {run_key}")
            
            # Create single prompts (zero-shot and few-shot)
            single_zero = create_prompt_relation_df_single(
                doc_rows, test_df, template_path_single, 
                examples=False, same_examples=False, 
                seed=seed, n_prompts=1, prompt_id=False
            )
            
            single_few = create_prompt_relation_df_single(
                doc_rows, test_df, template_path_single,
                examples=True, same_examples=True,
                seed=seed, n_prompts=1, prompt_id=False
            )
            
            # Create multi prompts (zero-shot and few-shot)
            multi_zero = create_prompt_relation_df_multi_by_docid(
                doc_rows, test_df, template_path_multi,
                examples=False, same_examples=False,
                seed=seed, n_prompts=1,
                number_relations=True, relations_entitys_separately=False
            )
            
            multi_few = create_prompt_relation_df_multi_by_docid(
                doc_rows, test_df, template_path_multi,
                examples=True, same_examples=True,
                seed=seed, n_prompts=1,
                number_relations=True, relations_entitys_separately=False
            )
            
            # Append to existing data
            # Single zero
            data["n_1"][run_key]["single_zero"].extend(single_zero['Prompt'].tolist())
            
            # Single examples
            data["n_1"][run_key]["single_examples"].extend(single_few['Prompt'].tolist())
            
            # Multi zero
            data["n_1"][run_key]["multi_zero"].extend(multi_zero['Prompt'].tolist())
            data["n_1"][run_key]["multi_relations"].extend(multi_zero['Multi_Relations'].tolist())
            data["n_1"][run_key]["multi_docid"].extend(multi_zero['Multi_DocID'].tolist())
            
            # Multi examples
            data["n_1"][run_key]["multi_examples"].extend(multi_few['Prompt'].tolist())
            
            # Append relations and doc_ids (these are shared across prompt types)
            if "relations" in data["n_1"][run_key]:
                # For single prompts, extend with individual relations
                data["n_1"][run_key]["relations"].extend(single_zero['Relation'].tolist())
            
            if "doc_ids" in data["n_1"][run_key]:
                data["n_1"][run_key]["doc_ids"].extend(single_zero['DocID'].tolist())
    
    # Save updated JSON
    output_path = json_path.replace(".json", "_complete.json")
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2)
    
    print(f"\nSaved complete dataset to: {output_path}")
    return output_path

"""
# Main execution
if __name__ == "__main__":
    # Define all possible classes
    ALL_CLASSES = [
        #'Association',
        #'Positive_Correlation',
        #'Negative_Correlation',
        #'Bind',
        #'Cotreatment',
        #'Comparison',
        'Drug_Interaction',
        'Conversion',
        'No_Relation'
    ]
    
    # Paths
    json_path = "LLM_benchmarks/Prompts/Test_callibration.json"
    template_single = "LLM_benchmarks/prompt_template_single.txt"
    template_multi = "LLM_benchmarks/prompt_template_multi.txt"
    
    # Load dataframes (you'll need to load these from your notebook)
    # merged_df_train = ...
    # merged_df_test = ...
    
    # Find missing classes
    missing = find_missing_classes(json_path, ALL_CLASSES)
    
    if missing:
        print(f"Missing classes found: {missing}")
        print(f"Will add {len(missing)} abstracts to the dataset\n")
        
        #Append missing classes
        
        append_missing_classes_to_json(
            json_path,
             merged_df_train,
             merged_df_test,
             template_single,
             template_multi,
             missing,
             seed=42
         )
    else:
        print("All classes are represented in the dataset!")
"""
# Out:
# '\n# Main execution\nif __name__ == "__main__":\n    # Define all possible classes\n    ALL_CLASSES = [\n        #\'Association\',\n        #\'Positive_Correlation\',\n        #\'Negative_Correlation\',\n        #\'Bind\',\n        #\'Cotreatment\',\n        #\'Comparison\',\n        \'Drug_Interaction\',\n        \'Conversion\',\n        \'No_Relation\'\n    ]\n\n    # Paths\n    json_path = "LLM_benchmarks/Prompts/Test_callibration.json"\n    template_single = "LLM_benchmarks/prompt_template_single.txt"\n    template_multi = "LLM_benchmarks/prompt_template_multi.txt"\n\n    # Load dataframes (you\'ll need to load these from your notebook)\n    # merged_df_train = ...\n    # merged_df_test = ...\n\n    # Find missing classes\n    missing = find_missing_classes(json_path, ALL_CLASSES)\n\n    if missing:\n        print(f"Missing classes found: {missing}")\n        print(f"Will add {len(missing)} abstracts to the dataset\n")\n\n        #Append missing classes\n\n        append_missing_classes_to_json(\n            json_path,\n             merged_df_train,\n             merged_df_test,\n             template_single,\n             template_multi,\n             missing,\n             seed=42\n         )\n    else:\n        print("All classes are represented in the dataset!")\n'

# %%
import json
import pandas as pd

def get_doc_ids_from_json(json_path, run_key="run_1"):
    """Extract all doc IDs from a JSON dataset for a specific run."""
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    doc_ids = data["n_1"][run_key]["doc_ids"]
    return set(doc_ids)


def find_missing_doc_ids(json_path_complete, json_path_incomplete):
    """
    Find doc IDs that are in the complete JSON but missing from the incomplete one.
    
    Args:
        json_path_complete: Path to the completed/reference JSON
        json_path_incomplete: Path to the JSON that needs completion
    
    Returns:
        list: Doc IDs that need to be added
    """
    complete_doc_ids = get_doc_ids_from_json(json_path_complete)
    incomplete_doc_ids = get_doc_ids_from_json(json_path_incomplete)
    
    missing_doc_ids = complete_doc_ids - incomplete_doc_ids
    
    return list(missing_doc_ids)


def append_missing_doc_ids_to_json(
    json_path,
    train_df,
    test_df,
    template_path_single,
    template_path_multi,
    missing_doc_ids,
    seed=42
):
    """
    Append prompts for missing doc IDs to existing JSON file.
    
    Args:
        json_path: Path to the JSON file to complete
        train_df: Training dataframe
        test_df: Test dataframe (for examples)
        template_path_single: Path to single prompt template
        template_path_multi: Path to multi prompt template
        missing_doc_ids: List of doc IDs to add
        seed: Random seed for reproducibility
    """
    # Load existing JSON
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    print(f"Adding {len(missing_doc_ids)} abstracts with doc IDs: {missing_doc_ids}\n")
    
    # For each run in the JSON
    for run_key in data["n_1"].keys():
        run_num = int(run_key.split("_")[1])
        
        for doc_id in missing_doc_ids:
            # Get all rows for this doc_id from training data
            doc_rows = train_df[train_df['doc_id'] == doc_id].copy()
            
            if doc_rows.empty:
                print(f"  Warning: Doc ID {doc_id} not found in training data")
                continue
            
            # Get the relation types for this doc_id (for logging)
            relations_in_doc = doc_rows['relation_type'].unique()
            print(f"  Adding abstract {doc_id} (relations: {list(relations_in_doc)}) to {run_key}")
            
            # Create single prompts (zero-shot and few-shot)
            single_zero = create_prompt_relation_df_single(
                doc_rows, test_df, template_path_single, 
                examples=False, same_examples=False, 
                seed=seed, n_prompts=1, prompt_id=False
            )
            
            single_few = create_prompt_relation_df_single(
                doc_rows, test_df, template_path_single,
                examples=True, same_examples=True,
                seed=seed, n_prompts=1, prompt_id=False
            )
            
            # Create multi prompts (zero-shot and few-shot)
            multi_zero = create_prompt_relation_df_multi_by_docid(
                doc_rows, test_df, template_path_multi,
                examples=False, same_examples=False,
                seed=seed, n_prompts=1,
                number_relations=True, relations_entitys_separately=False
            )
            
            multi_few = create_prompt_relation_df_multi_by_docid(
                doc_rows, test_df, template_path_multi,
                examples=True, same_examples=True,
                seed=seed, n_prompts=1,
                number_relations=True, relations_entitys_separately=False
            )
            
            # Append to existing data
            data["n_1"][run_key]["single_zero"].extend(single_zero['Prompt'].tolist())
            data["n_1"][run_key]["single_examples"].extend(single_few['Prompt'].tolist())
            data["n_1"][run_key]["multi_zero"].extend(multi_zero['Prompt'].tolist())
            data["n_1"][run_key]["multi_relations"].extend(multi_zero['Multi_Relations'].tolist())
            data["n_1"][run_key]["multi_docid"].extend(multi_zero['Multi_DocID'].tolist())
            data["n_1"][run_key]["multi_examples"].extend(multi_few['Prompt'].tolist())
            
            if "relations" in data["n_1"][run_key]:
                data["n_1"][run_key]["relations"].extend(single_zero['Relation'].tolist())
            
            if "doc_ids" in data["n_1"][run_key]:
                data["n_1"][run_key]["doc_ids"].extend(single_zero['DocID'].tolist())
    
    # Save updated JSON
    output_path = json_path.replace(".json", "_complete.json")
    with open(output_path, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=2)
    
    print(f"\nSaved complete dataset to: {output_path}")
    return output_path


# Main execution
if __name__ == "__main__":
    # Paths
    complete_json = "LLM_benchmarks/Prompts/backup/Test_callibration.json"
    incomplete_json = "LLM_benchmarks/Prompts/Test_callibration_binary.json"
    template_single = "LLM_benchmarks/prompt_template_single_binary.txt"
    template_multi = "LLM_benchmarks/prompt_template_multi _binary.txt"
    
    # Find missing doc IDs
    missing_doc_ids = find_missing_doc_ids(complete_json, incomplete_json)
    
    if missing_doc_ids:
        print(f"Missing doc IDs found: {missing_doc_ids}")
        print(f"Will add {len(missing_doc_ids)} abstracts to the dataset\n")
        
        # Load dataframes (you'll need to load these from your notebook)
        # merged_df_train = ...
        # merged_df_test = ...
        
        # Append missing doc IDs
        append_missing_doc_ids_to_json(
            incomplete_json,
            merged_df_train,
            merged_df_test,
            template_single,
            template_multi,
            missing_doc_ids,
            seed=42
        )
    else:
        print("All doc IDs from the complete dataset are already present!")
# Out:
# Missing doc IDs found: ['21070631', '16720068', '15266215']
# Will add 3 abstracts to the dataset
#
# Adding 3 abstracts with doc IDs: ['21070631', '16720068', '15266215']
#
#   Adding abstract 21070631 (relations: ['No_Relation', 'Relation']) to run_1
#   Adding abstract 16720068 (relations: ['Relation', 'No_Relation']) to run_1
#   Adding abstract 15266215 (relations: ['Relation', 'No_Relation']) to run_1
#   Adding abstract 21070631 (relations: ['No_Relation', 'Relation']) to run_2
#   Adding abstract 16720068 (relations: ['Relation', 'No_Relation']) to run_2
#   Adding abstract 15266215 (relations: ['Relation', 'No_Relation']) to run_2
#   Adding abstract 21070631 (relations: ['No_Relation', 'Relation']) to run_3
#   Adding abstract 16720068 (relations: ['Relation', 'No_Relation']) to run_3
#   Adding abstract 15266215 (relations: ['Relation', 'No_Relation']) to run_3
#   Adding abstract 21070631 (relations: ['No_Relation', 'Relation']) to run_4
#   Adding abstract 16720068 (relations: ['Relation', 'No_Relation']) to run_4
#   Adding abstract 15266215 (relations: ['Relation', 'No_Relation']) to run_4
#   Adding abstract 21070631 (relations: ['No_Relation', 'Relation']) to run_5
#   Adding abstract 16720068 (relations: ['Relation', 'No_Relation']) to run_5
#   Adding abstract 15266215 (relations: ['Relation', 'No_Relation']) to run_5
#
# Saved complete dataset to: LLM_benchmarks/Prompts/Test_callibration_binary_complete.json
